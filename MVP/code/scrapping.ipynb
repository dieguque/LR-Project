# %% [markdown]
# # Scpraping
#
#
# ### We use the Box Office Mojo https://www.boxofficemojo.com/ to getall the  2010-2019 movies data.

# %%
import requests
from requests import get
from bs4 import BeautifulSoup
from IPython.core.display import display, HTML
import pandas as pd
import numpy as np
import re
import dateutil.parser
import seaborn as sns

from time import sleep
from random import randint

# %% [markdown]
# ### Define general functions

# %%
def get_movie_value(soup, field):
    obj = soup.find(text=re.compile(field))
    if not obj:
        return None
    next_element = obj.findNext()
    if next_element:
        return next_element.text
    else:
        return None
    
def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %% [markdown]
# ### Define atribute functions

# %%
def get_movie_title(soup):
    title_element = soup.find("title")
    if not title_element:
        return None

    title_text = title_element.text
    if "-" in title_text:
        title_parts = title_text.split("-")
        if title_parts.count == 2:
            return title_parts[0].strip()
        else:
            return "-".join(title_parts[0:-1]).strip()
    else:
        return title_text.strip()


def get_movie_runtime(soup):
    runtimestring = get_movie_value(soup, "Running")
    try:
        runtime = runtimestring.split()
        minutes = int(runtime[0]) * 60 + int(runtime[2])
        return minutes
    except:
        return None


def get_movie_widest_release(soup):
    widest_release_value = get_movie_value(soup, "Widest Release")
    if not widest_release_value:
        return None
    widest_release_value = widest_release_value.replace(",", "").split(" ")[0]
    widest_release_value = widest_release_value.strip()
    return int(widest_release_value)    
    
    
def get_movie_domestic_gross(soup):
    moneystring = (soup.find(class_="mojo-performance-summary-table").find_all("span", class_="money")[0].text)
    if not moneystring:
        return None
    return int(moneystring.replace("$", "").replace(",", ""))


def get_movie_worldwide_gross(soup):
    moneystring = (soup.find(class_="mojo-performance-summary-table").find_all("span", class_="money")[-1].text)
    if not moneystring:
        return None
    return int(moneystring.replace("$", "").replace(",", ""))

def get_movie_distributor(soup):
    distributor1 = get_movie_value(soup, "Distributor")
    distributor = distributor1.split('See')[0]
    if not distributor:
        return None
    return distributor.strip()

def get_movie_opening_gross(soup):
    element1 = soup.find(class_="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile")
    if not element1:
        return None
    element2 = element1.find("span", class_="money")
    if not element2:
        return None
    opening = element2.text.replace("$", "").replace(",", "")
    return int(opening)

def get_movie_budget(soup):
    budget1 = get_movie_value(soup, "Budget")
    try:
        budget = budget1.replace("$", "").replace(",", "")
        return int(budget)
    except:
        return None

def get_release_date(soup):
    date = get_movie_value(soup, "Release Date").split('-')[0].split('(')[0].strip()
    date = to_date(date)
    if not date:
        return None
    return date #.strip()    

def get_movie_rating(soup):
    rating_value = get_movie_value(soup, "MPAA")
    if not rating_value:
        return None
    return rating_value.strip()

def get_movie_genres(soup):
    genres_value = get_movie_value(soup, "Genres")
    if not genres_value:
        return None
    #genres_value = genres_value.replace('\n    \n       ','')
    return genres_value.split()#.strip()

# %% [markdown]
# ### Combining all those attributes

# %%
def get_movie_data(url):
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, "lxml")

    title = get_movie_title(soup)
    domestic_gross = get_movie_domestic_gross(soup)
    #international_gross = get_movie_international_gross(soup)
    worldwide_gross = get_movie_worldwide_gross(soup)
    movie_distributor = get_movie_distributor(soup)
    movie_opening_gross = get_movie_opening_gross(soup)
    movie_budget =get_movie_budget(soup)
    release_date = get_release_date(soup)
    runtime = get_movie_runtime(soup)
    movie_widest_release = get_movie_widest_release(soup)
    rating = get_movie_rating(soup)
    movie_genres = get_movie_genres(soup)

    headers = ["title", "domestic", "worldwide", "distributor", "opening", "budget", "date", "runtime", "widest", "rating", "genres"] #"international",
    movie_dict = dict(zip(headers, [title, domestic_gross, worldwide_gross, movie_distributor, movie_opening_gross, movie_budget, release_date, runtime, movie_widest_release, rating, movie_genres])) #international_gross

    return movie_dict

# %% [markdown]
# ### Scrape the atribues

# %%
def get_urls():
    # Create a list of all urls
    urls = []
    for year in range(2010, 2020):
        url = (
            "https://www.boxofficemojo.com/year/"
            + str(year)
            + "/?grossesOption=totalGrosses"
        )
        urls.append(url)
        
        
        all_titles = []
    for url in urls:
        page = requests.get(url)
        soup = BeautifulSoup(page.text, "lxml")
        titles = soup.find_all(
            "td", class_="a-text-left mojo-field-type-release mojo-cell-wide"
        )
        for title in titles:
            all_titles.append(
                "https://www.boxofficemojo.com/" + title.select("a")[0].get("href")
            )
    return all_titles


urls = get_urls()

# Use thise code to verify the scraping process
"""count = 1
for url in urls:
    print(f"{count}: {url}")
    movie_data = get_movie_data(url)
    print(movie_data)
    count = count + 1"""
    #sleep(randint(1, 2))
# Out:
# 'count = 1\nfor url in urls:\n    print(f"{count}: {url}")\n    movie_data = get_movie_data(url)\n    print(movie_data)\n    count = count + 1'

# %% [markdown]
# ### Create a dicctionary

# %%
movies_list = []
for url in urls:
    movies_list.append(get_movie_data(url))
    
movies_list
# Out:
# [{'title': 'Toy Story 3',
#   'domestic': 415004880,
#   'worldwide': 1066969703,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 110307189,
#   'budget': 200000000,
#   'date': datetime.datetime(2010, 6, 18, 0, 0),
#   'runtime': 103,
#   'widest': 4028,
#   'rating': None,
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Alice in Wonderland',
#   'domestic': 334191110,
#   'worldwide': 1025467110,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 116101023,
#   'budget': 200000000,
#   'date': datetime.datetime(2010, 3, 5, 0, 0),
#   'runtime': 108,
#   'widest': 3739,
#   'rating': 'PG',
#   'genres': ['Adventure', 'Family', 'Fantasy']},
#  {'title': 'Iron Man 2',
#   'domestic': 312433331,
#   'worldwide': 623933331,
#   'distributor': 'Paramount Pictures',
#   'opening': 128122480,
#   'budget': 200000000,
#   'date': datetime.datetime(2010, 5, 7, 0, 0),
#   'runtime': 124,
#   'widest': 4390,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'The Twilight Saga: Eclipse',
#   'domestic': 300531751,
#   'worldwide': 698491347,
#   'distributor': 'Summit Entertainment',
#   'opening': 64832191,
#   'budget': 68000000,
#   'date': datetime.datetime(2010, 6, 30, 0, 0),
#   'runtime': 124,
#   'widest': 4468,
#   'rating': 'PG-13',
#   'genres': ['Action',
#    'Adventure',
#    'Drama',
#    'Fantasy',
#    'Romance',
#    'Thriller']},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'domestic': 295983305,
#   'worldwide': 976536918,
#   'distributor': 'Warner Bros.',
#   'opening': 125017372,
#   'budget': None,
#   'date': datetime.datetime(2010, 11, 19, 0, 0),
#   'runtime': 146,
#   'widest': 4125,
#   'rating': 'PG-13',
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'title': 'Inception',
#   'domestic': 292576195,
#   'worldwide': 826137188,
#   'distributor': 'Warner Bros.',
#   'opening': 62785337,
#   'budget': 160000000,
#   'date': datetime.datetime(2010, 7, 16, 0, 0),
#   'runtime': 148,
#   'widest': 3792,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'Despicable Me',
#   'domestic': 251513985,
#   'worldwide': 543113985,
#   'distributor': 'Universal Pictures',
#   'opening': 56397125,
#   'budget': 69000000,
#   'date': datetime.datetime(2010, 7, 9, 0, 0),
#   'runtime': 95,
#   'widest': 3602,
#   'rating': 'PG',
#   'genres': ['Animation', 'Comedy', 'Crime', 'Family', 'Fantasy']},
#  {'title': 'Shrek Forever After',
#   'domestic': 238736787,
#   'worldwide': 752600867,
#   'distributor': 'DreamWorks',
#   'opening': 70838207,
#   'budget': 165000000,
#   'date': datetime.datetime(2010, 5, 21, 0, 0),
#   'runtime': 93,
#   'widest': 4386,
#   'rating': 'PG',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Romance']},
#  {'title': 'How to Train Your Dragon',
#   'domestic': 217581231,
#   'worldwide': 494878759,
#   'distributor': 'DreamWorks',
#   'opening': 43732319,
#   'budget': 165000000,
#   'date': datetime.datetime(2010, 3, 26, 0, 0),
#   'runtime': 98,
#   'widest': 4060,
#   'rating': 'PG',
#   'genres': ['Action', 'Adventure', 'Animation', 'Family', 'Fantasy']},
#  {'title': 'Tangled',
#   'domestic': 200821936,
#   'worldwide': 592461732,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 48767052,
#   'budget': 260000000,
#   'date': datetime.datetime(2010, 11, 24, 0, 0),
#   'runtime': 100,
#   'widest': 3603,
#   'rating': 'PG',
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical',
#    'Romance']},
#  {'title': 'The Karate Kid',
#   'domestic': 176591618,
#   'worldwide': 359126022,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 55665805,
#   'budget': 40000000,
#   'date': datetime.datetime(2010, 6, 11, 0, 0),
#   'runtime': 140,
#   'widest': 3740,
#   'rating': 'PG',
#   'genres': ['Action', 'Drama', 'Family', 'Sport']},
#  {'title': 'TRON: Legacy',
#   'domestic': 172062763,
#   'worldwide': 400062763,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 44026211,
#   'budget': 170000000,
#   'date': datetime.datetime(2010, 12, 17, 0, 0),
#   'runtime': 125,
#   'widest': 3451,
#   'rating': 'PG',
#   'genres': ['Action', 'Adventure', 'Sci-Fi']},
#  {'title': 'True Grit',
#   'domestic': 171243005,
#   'worldwide': 252276927,
#   'distributor': 'Paramount Pictures',
#   'opening': 24830443,
#   'budget': 38000000,
#   'date': datetime.datetime(2010, 12, 22, 0, 0),
#   'runtime': 110,
#   'widest': 3464,
#   'rating': 'PG-13',
#   'genres': ['Drama', 'Western']},
#  {'title': 'Clash of the Titans',
#   'domestic': 163214888,
#   'worldwide': 493214993,
#   'distributor': 'Warner Bros.',
#   'opening': 61235105,
#   'budget': 125000000,
#   'date': datetime.datetime(2010, 4, 2, 0, 0),
#   'runtime': 106,
#   'widest': 3802,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Fantasy']},
#  {'title': 'Grown Ups',
#   'domestic': 162001186,
#   'worldwide': 271430189,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 40506562,
#   'budget': 80000000,
#   'date': datetime.datetime(2010, 6, 25, 0, 0),
#   'runtime': 102,
#   'widest': 3534,
#   'rating': 'PG-13',
#   'genres': ['Comedy']},
#  {'title': 'Little Fockers',
#   'domestic': 148438600,
#   'worldwide': 310650585,
#   'distributor': 'Universal Pictures',
#   'opening': 30833665,
#   'budget': 100000000,
#   'date': datetime.datetime(2010, 12, 22, 0, 0),
#   'runtime': 98,
#   'widest': 3675,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'Megamind',
#   'domestic': 148415853,
#   'worldwide': 321885765,
#   'distributor': 'DreamWorks',
#   'opening': 46016833,
#   'budget': 130000000,
#   'date': datetime.datetime(2010, 11, 5, 0, 0),
#   'runtime': 95,
#   'widest': 3949,
#   'rating': 'PG',
#   'genres': ['Action', 'Animation', 'Comedy', 'Family', 'Sci-Fi']},
#  {'title': "The King's Speech",
#   'domestic': 135453143,
#   'worldwide': 423999102,
#   'distributor': 'The Weinstein Company',
#   'opening': 355450,
#   'budget': 15000000,
#   'date': datetime.datetime(2010, 11, 26, 0, 0),
#   'runtime': 118,
#   'widest': 2584,
#   'rating': 'R',
#   'genres': ['Biography', 'Drama', 'History']},
#  {'title': 'The Last Airbender',
#   'domestic': 131772187,
#   'worldwide': 319713881,
#   'distributor': 'Paramount Pictures',
#   'opening': 40325019,
#   'budget': 150000000,
#   'date': datetime.datetime(2010, 7, 1, 0, 0),
#   'runtime': 103,
#   'widest': 3203,
#   'rating': 'PG',
#   'genres': ['Action', 'Adventure', 'Family', 'Fantasy']},
#  {'title': 'Shutter Island',
#   'domestic': 128012934,
#   'worldwide': 294804195,
#   'distributor': 'Paramount Pictures',
#   'opening': 41062440,
#   'budget': 80000000,
#   'date': datetime.datetime(2010, 2, 19, 0, 0),
#   'runtime': 138,
#   'widest': 3356,
#   'rating': 'R',
#   'genres': ['Mystery', 'Thriller']},
#  {'title': 'The Other Guys',
#   'domestic': 119219978,
#   'worldwide': 170458922,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 35543162,
#   'budget': 100000000,
#   'date': datetime.datetime(2010, 8, 6, 0, 0),
#   'runtime': 107,
#   'widest': 3651,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Comedy', 'Crime']},
#  {'title': 'Salt',
#   'domestic': 118311368,
#   'worldwide': 293503354,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 36011243,
#   'budget': 110000000,
#   'date': datetime.datetime(2010, 7, 23, 0, 0),
#   'runtime': 100,
#   'widest': 3612,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Thriller']},
#  {'title': 'Jackass 3D',
#   'domestic': 117229692,
#   'worldwide': 171685792,
#   'distributor': 'Paramount Pictures',
#   'opening': 50353641,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 10, 15, 0, 0),
#   'runtime': 95,
#   'widest': 3139,
#   'rating': 'R',
#   'genres': ['Action', 'Comedy', 'Documentary']},
#  {'title': "Valentine's Day",
#   'domestic': 110485654,
#   'worldwide': 216485654,
#   'distributor': 'Warner Bros.',
#   'opening': 56260707,
#   'budget': 52000000,
#   'date': datetime.datetime(2010, 2, 12, 0, 0),
#   'runtime': 125,
#   'widest': 3665,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'Black Swan',
#   'domestic': 106954678,
#   'worldwide': 329398046,
#   'distributor': 'Fox Searchlight Pictures',
#   'opening': 1443809,
#   'budget': 13000000,
#   'date': datetime.datetime(2010, 12, 3, 0, 0),
#   'runtime': 108,
#   'widest': 2407,
#   'rating': 'R',
#   'genres': ['Drama', 'Thriller']},
#  {'title': 'Robin Hood',
#   'domestic': 105269730,
#   'worldwide': 321669741,
#   'distributor': 'Universal Pictures',
#   'opening': 36063385,
#   'budget': 200000000,
#   'date': datetime.datetime(2010, 5, 14, 0, 0),
#   'runtime': 140,
#   'widest': 3505,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Drama', 'History']},
#  {'title': 'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   'domestic': 104386950,
#   'worldwide': 415686217,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 24005069,
#   'budget': 155000000,
#   'date': datetime.datetime(2010, 12, 10, 0, 0),
#   'runtime': 113,
#   'widest': 3555,
#   'rating': 'PG',
#   'genres': ['Adventure', 'Family', 'Fantasy']},
#  {'title': 'The Expendables',
#   'domestic': 103068524,
#   'worldwide': 274470394,
#   'distributor': 'Lionsgate',
#   'opening': 34825135,
#   'budget': 80000000,
#   'date': datetime.datetime(2010, 8, 13, 0, 0),
#   'runtime': 103,
#   'widest': 3398,
#   'rating': 'R',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Due Date',
#   'domestic': 100539043,
#   'worldwide': 211780824,
#   'distributor': 'Warner Bros.',
#   'opening': 32689406,
#   'budget': 65000000,
#   'date': datetime.datetime(2010, 11, 5, 0, 0),
#   'runtime': 95,
#   'widest': 3365,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama']},
#  {'title': 'Yogi Bear',
#   'domestic': 100246011,
#   'worldwide': 203509374,
#   'distributor': 'Warner Bros.',
#   'opening': 16411322,
#   'budget': 80000000,
#   'date': datetime.datetime(2010, 12, 17, 0, 0),
#   'runtime': 81,
#   'widest': 3515,
#   'rating': 'PG',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'title': 'Date Night',
#   'domestic': 98711404,
#   'worldwide': 152263880,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 25207599,
#   'budget': 55000000,
#   'date': datetime.datetime(2010, 4, 9, 0, 0),
#   'runtime': 88,
#   'widest': 3380,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Crime', 'Romance', 'Thriller']},
#  {'title': 'The Social Network',
#   'domestic': 96962694,
#   'worldwide': 224920315,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 22445653,
#   'budget': 40000000,
#   'date': datetime.datetime(2010, 10, 1, 0, 0),
#   'runtime': None,
#   'widest': 2921,
#   'rating': 'PG-13',
#   'genres': ['Biography', 'Drama']},
#  {'title': 'Sex and the City 2',
#   'domestic': 95347692,
#   'worldwide': 290745055,
#   'distributor': 'Warner Bros.',
#   'opening': 31001870,
#   'budget': 100000000,
#   'date': datetime.datetime(2010, 5, 27, 0, 0),
#   'runtime': 146,
#   'widest': 3445,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'The Book of Eli',
#   'domestic': 94835059,
#   'worldwide': 157107755,
#   'distributor': 'Warner Bros.',
#   'opening': 32789494,
#   'budget': 80000000,
#   'date': datetime.datetime(2010, 1, 15, 0, 0),
#   'runtime': 118,
#   'widest': 3111,
#   'rating': 'R',
#   'genres': ['Action', 'Adventure', 'Drama', 'Thriller']},
#  {'title': 'The Fighter',
#   'domestic': 93617009,
#   'worldwide': 129190869,
#   'distributor': 'Paramount Pictures',
#   'opening': 300010,
#   'budget': 25000000,
#   'date': datetime.datetime(2010, 12, 10, 0, 0),
#   'runtime': 116,
#   'widest': 2534,
#   'rating': 'R',
#   'genres': ['Biography', 'Drama', 'Sport']},
#  {'title': 'The Town',
#   'domestic': 92186262,
#   'worldwide': 154026136,
#   'distributor': 'Warner Bros.',
#   'opening': 23808032,
#   'budget': 37000000,
#   'date': datetime.datetime(2010, 9, 17, 0, 0),
#   'runtime': 125,
#   'widest': 2935,
#   'rating': 'R',
#   'genres': ['Crime', 'Drama', 'Thriller']},
#  {'title': 'Prince of Persia: The Sands of Time',
#   'domestic': 90759676,
#   'worldwide': 336365676,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 30095259,
#   'budget': 200000000,
#   'date': datetime.datetime(2010, 5, 28, 0, 0),
#   'runtime': 116,
#   'widest': 3646,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Fantasy']},
#  {'title': 'RED',
#   'domestic': 90380162,
#   'worldwide': 199006387,
#   'distributor': 'Summit Entertainment',
#   'opening': 21761408,
#   'budget': 58000000,
#   'date': datetime.datetime(2010, 10, 15, 0, 0),
#   'runtime': 111,
#   'widest': 3349,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Comedy', 'Crime', 'Thriller']},
#  {'title': 'Percy Jackson & the Olympians: The Lightning Thief',
#   'domestic': 88768303,
#   'worldwide': 226497209,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 31236067,
#   'budget': 95000000,
#   'date': datetime.datetime(2010, 2, 12, 0, 0),
#   'runtime': 118,
#   'widest': 3396,
#   'rating': 'PG',
#   'genres': ['Adventure', 'Family', 'Fantasy']},
#  {'title': 'Paranormal Activity 2',
#   'domestic': 84752907,
#   'worldwide': 177512032,
#   'distributor': 'Paramount Pictures',
#   'opening': 40678424,
#   'budget': 3000000,
#   'date': datetime.datetime(2010, 10, 22, 0, 0),
#   'runtime': 91,
#   'widest': 3239,
#   'rating': 'R',
#   'genres': ['Horror', 'Mystery']},
#  {'title': 'Unstoppable',
#   'domestic': 81562942,
#   'worldwide': 167805466,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 22688457,
#   'budget': 100000000,
#   'date': datetime.datetime(2010, 11, 12, 0, 0),
#   'runtime': 98,
#   'widest': 3261,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Thriller']},
#  {'title': 'Eat Pray Love',
#   'domestic': 80574010,
#   'worldwide': 204594016,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 23104523,
#   'budget': 60000000,
#   'date': datetime.datetime(2010, 8, 13, 0, 0),
#   'runtime': 133,
#   'widest': 3108,
#   'rating': 'PG-13',
#   'genres': ['Biography', 'Drama', 'Romance']},
#  {'title': 'Dear John',
#   'domestic': 80014842,
#   'worldwide': 114984666,
#   'distributor': 'Screen Gems',
#   'opening': 30468614,
#   'budget': 25000000,
#   'date': datetime.datetime(2010, 2, 5, 0, 0),
#   'runtime': 108,
#   'widest': 3062,
#   'rating': 'PG-13',
#   'genres': ['Drama', 'Mystery', 'Romance', 'Thriller', 'War']},
#  {'title': 'The A-Team',
#   'domestic': 77222099,
#   'worldwide': 177238796,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 25669455,
#   'budget': 110000000,
#   'date': datetime.datetime(2010, 6, 11, 0, 0),
#   'runtime': 117,
#   'widest': 3544,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Thriller']},
#  {'title': 'Knight and Day 2010 Re-release',
#   'domestic': 76423035,
#   'worldwide': 261930436,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 20139985,
#   'budget': 117000000,
#   'date': datetime.datetime(2010, 6, 23, 0, 0),
#   'runtime': 109,
#   'widest': 3104,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Comedy']},
#  {'title': 'Dinner for Schmucks',
#   'domestic': 73026337,
#   'worldwide': 86855739,
#   'distributor': 'DreamWorks',
#   'opening': 23527839,
#   'budget': 69000000,
#   'date': datetime.datetime(2010, 7, 30, 0, 0),
#   'runtime': 114,
#   'widest': 3046,
#   'rating': 'PG-13',
#   'genres': ['Comedy']},
#  {'title': 'The Tourist',
#   'domestic': 67631157,
#   'worldwide': 278780441,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 16472458,
#   'budget': 100000000,
#   'date': datetime.datetime(2010, 12, 10, 0, 0),
#   'runtime': 103,
#   'widest': 2756,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Thriller']},
#  {'title': 'The Bounty Hunter',
#   'domestic': 67061228,
#   'worldwide': 136333522,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 20686423,
#   'budget': 40000000,
#   'date': datetime.datetime(2010, 3, 19, 0, 0),
#   'runtime': 110,
#   'widest': 3118,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Comedy', 'Romance']},
#  {'title': 'Diary of a Wimpy Kid',
#   'domestic': 64003625,
#   'worldwide': 76196538,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 22126166,
#   'budget': 15000000,
#   'date': datetime.datetime(2010, 3, 19, 0, 0),
#   'runtime': None,
#   'widest': 3083,
#   'rating': 'PG',
#   'genres': ['Animation', 'Comedy', 'Drama', 'Family']},
#  {'title': "The Sorcerer's Apprentice",
#   'domestic': 63150991,
#   'worldwide': 215283742,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 17619622,
#   'budget': 150000000,
#   'date': datetime.datetime(2010, 7, 14, 0, 0),
#   'runtime': 109,
#   'widest': 3504,
#   'rating': 'PG',
#   'genres': ['Action', 'Adventure', 'Family', 'Fantasy']},
#  {'title': 'A Nightmare on Elm Street',
#   'domestic': 63075011,
#   'worldwide': 115694863,
#   'distributor': 'Warner Bros.',
#   'opening': 32902299,
#   'budget': 35000000,
#   'date': datetime.datetime(2010, 4, 30, 0, 0),
#   'runtime': 95,
#   'widest': 3332,
#   'rating': 'R',
#   'genres': ['Crime', 'Drama', 'Horror', 'Mystery']},
#  {'title': 'The Last Song',
#   'domestic': 62950384,
#   'worldwide': 89137047,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 16007426,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 3, 31, 0, 0),
#   'runtime': 108,
#   'widest': 2794,
#   'rating': 'PG',
#   'genres': ['Drama', 'Music', 'Romance']},
#  {'title': 'The Wolfman',
#   'domestic': 61979680,
#   'worldwide': 139789765,
#   'distributor': 'Universal Pictures',
#   'opening': 31479235,
#   'budget': 150000000,
#   'date': datetime.datetime(2010, 2, 12, 0, 0),
#   'runtime': 103,
#   'widest': 3223,
#   'rating': 'R',
#   'genres': ['Drama', 'Fantasy', 'Horror', 'Thriller']},
#  {'title': 'Get Him to the Greek',
#   'domestic': 60974475,
#   'worldwide': 91720255,
#   'distributor': 'Universal Pictures',
#   'opening': 17570955,
#   'budget': 40000000,
#   'date': datetime.datetime(2010, 6, 4, 0, 0),
#   'runtime': 109,
#   'widest': 2702,
#   'rating': 'R',
#   'genres': ['Comedy', 'Music']},
#  {'title': 'Resident Evil: Afterlife',
#   'domestic': 60128566,
#   'worldwide': 300228084,
#   'distributor': 'Screen Gems',
#   'opening': 26650264,
#   'budget': 60000000,
#   'date': datetime.datetime(2010, 9, 10, 0, 0),
#   'runtime': 96,
#   'widest': 3209,
#   'rating': 'R',
#   'genres': ['Action', 'Adventure', 'Horror', 'Sci-Fi']},
#  {'title': 'Why Did I Get Married Too?',
#   'domestic': 60095852,
#   'worldwide': 60673972,
#   'distributor': 'Lionsgate',
#   'opening': 29289537,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 4, 2, 0, 0),
#   'runtime': 121,
#   'widest': 2155,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Tooth Fairy',
#   'domestic': 60022256,
#   'worldwide': 112462508,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 14010409,
#   'budget': 48000000,
#   'date': datetime.datetime(2010, 1, 22, 0, 0),
#   'runtime': 101,
#   'widest': 3345,
#   'rating': 'PG',
#   'genres': ['Comedy', 'Family', 'Fantasy', 'Sport']},
#  {'title': 'Secretariat',
#   'domestic': 59713955,
#   'worldwide': 60321861,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 12694770,
#   'budget': 35000000,
#   'date': datetime.datetime(2010, 10, 8, 0, 0),
#   'runtime': 123,
#   'widest': 3108,
#   'rating': 'PG',
#   'genres': ['Biography', 'Drama', 'Family', 'History', 'Sport']},
#  {'title': 'Easy A',
#   'domestic': 58401464,
#   'worldwide': 75026216,
#   'distributor': 'Screen Gems',
#   'opening': 17734040,
#   'budget': 8000000,
#   'date': datetime.datetime(2010, 9, 17, 0, 0),
#   'runtime': 92,
#   'widest': 2974,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Takers',
#   'domestic': 57744720,
#   'worldwide': 69055695,
#   'distributor': 'Screen Gems',
#   'opening': 20512304,
#   'budget': 32000000,
#   'date': datetime.datetime(2010, 8, 27, 0, 0),
#   'runtime': 107,
#   'widest': 2206,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Crime', 'Thriller']},
#  {'title': "Legend of the Guardians: The Owls of Ga'Hoole",
#   'domestic': 55675313,
#   'worldwide': 140073390,
#   'distributor': 'Warner Bros.',
#   'opening': 16112211,
#   'budget': 80000000,
#   'date': datetime.datetime(2010, 9, 24, 0, 0),
#   'runtime': 97,
#   'widest': 3575,
#   'rating': 'PG',
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Family',
#    'Fantasy',
#    'Mystery',
#    'Thriller',
#    'War']},
#  {'title': 'Life as We Know It',
#   'domestic': 53374681,
#   'worldwide': 105734416,
#   'distributor': 'Warner Bros.',
#   'opening': 14506464,
#   'budget': 38000000,
#   'date': datetime.datetime(2010, 10, 8, 0, 0),
#   'runtime': 115,
#   'widest': 3150,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Letters to Juliet',
#   'domestic': 53032453,
#   'worldwide': 79293444,
#   'distributor': 'Summit Entertainment',
#   'opening': 13540486,
#   'budget': 30000000,
#   'date': datetime.datetime(2010, 5, 14, 0, 0),
#   'runtime': 105,
#   'widest': 2975,
#   'rating': 'PG',
#   'genres': ['Adventure', 'Comedy', 'Drama', 'Romance']},
#  {'title': 'Hubble 3D',
#   'domestic': 52522904,
#   'worldwide': 74249729,
#   'distributor': 'Warner Bros.',
#   'opening': 413477,
#   'budget': None,
#   'date': datetime.datetime(2010, 3, 19, 0, 0),
#   'runtime': None,
#   'widest': 151,
#   'rating': None,
#   'genres': ['Documentary']},
#  {'title': 'Wall Street: Money Never Sleeps',
#   'domestic': 52474616,
#   'worldwide': 134748021,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 19011188,
#   'budget': 70000000,
#   'date': datetime.datetime(2010, 9, 24, 0, 0),
#   'runtime': 133,
#   'widest': 3597,
#   'rating': 'PG-13',
#   'genres': ['Drama']},
#  {'title': 'Predators',
#   'domestic': 52000688,
#   'worldwide': 127233108,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 24760882,
#   'budget': 40000000,
#   'date': datetime.datetime(2010, 7, 9, 0, 0),
#   'runtime': 107,
#   'widest': 2669,
#   'rating': 'R',
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'title': 'Hot Tub Time Machine',
#   'domestic': 50287556,
#   'worldwide': 64735752,
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'opening': 14020502,
#   'budget': 36000000,
#   'date': datetime.datetime(2010, 3, 26, 0, 0),
#   'runtime': 101,
#   'widest': 2771,
#   'rating': 'R',
#   'genres': ['Comedy', 'Sci-Fi']},
#  {'title': 'Kick-Ass',
#   'domestic': 48071303,
#   'worldwide': 96188903,
#   'distributor': 'Lionsgate',
#   'opening': 19828687,
#   'budget': 30000000,
#   'date': datetime.datetime(2010, 4, 16, 0, 0),
#   'runtime': 117,
#   'widest': 3065,
#   'rating': 'R',
#   'genres': ['Action', 'Comedy', 'Crime']},
#  {'title': 'Killers',
#   'domestic': 47059963,
#   'worldwide': 98159963,
#   'distributor': 'Lionsgate',
#   'opening': 15837266,
#   'budget': 75000000,
#   'date': datetime.datetime(2010, 6, 4, 0, 0),
#   'runtime': 100,
#   'widest': 2859,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Comedy', 'Romance', 'Thriller']},
#  {'title': 'Saw: The Final Chapter',
#   'domestic': 45710178,
#   'worldwide': 136150434,
#   'distributor': 'Lionsgate',
#   'opening': 22530123,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 10, 29, 0, 0),
#   'runtime': 90,
#   'widest': 2808,
#   'rating': 'R',
#   'genres': ['Crime', 'Horror', 'Mystery']},
#  {'title': 'Cop Out',
#   'domestic': 44875481,
#   'worldwide': 55611001,
#   'distributor': 'Warner Bros.',
#   'opening': 18211126,
#   'budget': 30000000,
#   'date': datetime.datetime(2010, 2, 26, 0, 0),
#   'runtime': 107,
#   'widest': 3150,
#   'rating': 'R',
#   'genres': ['Action', 'Comedy', 'Crime']},
#  {'title': 'Cats & Dogs: The Revenge of Kitty Galore',
#   'domestic': 43585753,
#   'worldwide': 112483764,
#   'distributor': 'Warner Bros.',
#   'opening': 12279363,
#   'budget': 85000000,
#   'date': datetime.datetime(2010, 7, 30, 0, 0),
#   'runtime': 82,
#   'widest': 3705,
#   'rating': 'PG',
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Thriller']},
#  {'title': 'Edge of Darkness',
#   'domestic': 43313890,
#   'worldwide': 81126522,
#   'distributor': 'Warner Bros.',
#   'opening': 17214384,
#   'budget': 80000000,
#   'date': datetime.datetime(2010, 1, 29, 0, 0),
#   'runtime': 117,
#   'widest': 3066,
#   'rating': 'R',
#   'genres': ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller']},
#  {'title': "Gulliver's Travels",
#   'domestic': 42779261,
#   'worldwide': 237382724,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 6307691,
#   'budget': 112000000,
#   'date': datetime.datetime(2010, 12, 25, 0, 0),
#   'runtime': 85,
#   'widest': 3089,
#   'rating': 'PG',
#   'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy']},
#  {'title': 'Death at a Funeral',
#   'domestic': 42739347,
#   'worldwide': 49050886,
#   'distributor': 'Screen Gems',
#   'opening': 16217540,
#   'budget': 21000000,
#   'date': datetime.datetime(2010, 4, 16, 0, 0),
#   'runtime': 92,
#   'widest': 2459,
#   'rating': 'R',
#   'genres': ['Comedy']},
#  {'title': 'Step Up 3D',
#   'domestic': 42400223,
#   'worldwide': 159291809,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 15812311,
#   'budget': 30000000,
#   'date': datetime.datetime(2010, 8, 6, 0, 0),
#   'runtime': 107,
#   'widest': 2439,
#   'rating': 'PG-13',
#   'genres': ['Drama', 'Music', 'Romance']},
#  {'title': 'The Last Exorcism',
#   'domestic': 41034350,
#   'worldwide': 69432527,
#   'distributor': 'Lionsgate',
#   'opening': 20366613,
#   'budget': 1800000,
#   'date': datetime.datetime(2010, 8, 27, 0, 0),
#   'runtime': 87,
#   'widest': 2874,
#   'rating': 'PG-13',
#   'genres': ['Horror', 'Mystery', 'Thriller']},
#  {'title': 'Legion',
#   'domestic': 40168080,
#   'worldwide': 67918658,
#   'distributor': 'Screen Gems',
#   'opening': 17501625,
#   'budget': 26000000,
#   'date': datetime.datetime(2010, 1, 22, 0, 0),
#   'runtime': 100,
#   'widest': 2476,
#   'rating': 'R',
#   'genres': ['Action', 'Fantasy', 'Horror']},
#  {'title': 'Burlesque',
#   'domestic': 39440655,
#   'worldwide': 89519773,
#   'distributor': 'Screen Gems',
#   'opening': 11947744,
#   'budget': 55000000,
#   'date': datetime.datetime(2010, 11, 24, 0, 0),
#   'runtime': 119,
#   'widest': 3037,
#   'rating': 'PG-13',
#   'genres': ['Drama', 'Music', 'Musical', 'Romance']},
#  {'title': 'The Crazies',
#   'domestic': 39123589,
#   'worldwide': 54806823,
#   'distributor': 'Overture Films',
#   'opening': 16067552,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 2, 26, 0, 0),
#   'runtime': 101,
#   'widest': 2479,
#   'rating': 'R',
#   'genres': ['Horror', 'Mystery', 'Thriller']},
#  {'title': 'For Colored Girls',
#   'domestic': 37729698,
#   'worldwide': 37981984,
#   'distributor': 'Lionsgate',
#   'opening': 19497324,
#   'budget': 21000000,
#   'date': datetime.datetime(2010, 11, 5, 0, 0),
#   'runtime': 134,
#   'widest': 2127,
#   'rating': 'R',
#   'genres': ['Drama']},
#  {'title': 'The Back-up Plan',
#   'domestic': 37490007,
#   'worldwide': 77477008,
#   'distributor': 'CBS Films',
#   'opening': 12201710,
#   'budget': 35000000,
#   'date': datetime.datetime(2010, 4, 23, 0, 0),
#   'runtime': 104,
#   'widest': 3280,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'Vampires Suck',
#   'domestic': 36661504,
#   'worldwide': 80547866,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 12202831,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 8, 18, 0, 0),
#   'runtime': 82,
#   'widest': 3233,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Family', 'Horror']},
#  {'title': 'The American',
#   'domestic': 35606376,
#   'worldwide': 67876281,
#   'distributor': 'Focus Features',
#   'opening': 13177790,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 9, 1, 0, 0),
#   'runtime': 105,
#   'widest': 2833,
#   'rating': 'R',
#   'genres': ['Crime', 'Drama', 'Thriller']},
#  {'title': 'Green Zone',
#   'domestic': 35053660,
#   'worldwide': 94882549,
#   'distributor': 'Universal Pictures',
#   'opening': 14309295,
#   'budget': 100000000,
#   'date': datetime.datetime(2010, 3, 12, 0, 0),
#   'runtime': 115,
#   'widest': 3004,
#   'rating': 'R',
#   'genres': ['Action', 'Drama', 'Thriller', 'War']},
#  {'title': 'Marmaduke',
#   'domestic': 33644788,
#   'worldwide': 83761844,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 11599661,
#   'budget': 50000000,
#   'date': datetime.datetime(2010, 6, 4, 0, 0),
#   'runtime': 99,
#   'widest': 3213,
#   'rating': 'PG',
#   'genres': ['Animation', 'Comedy', 'Family']},
#  {'title': 'Devil',
#   'domestic': 33601190,
#   'worldwide': 62695489,
#   'distributor': 'Universal Pictures',
#   'opening': 12289375,
#   'budget': None,
#   'date': datetime.datetime(2010, 9, 17, 0, 0),
#   'runtime': 80,
#   'widest': 2811,
#   'rating': 'PG-13',
#   'genres': ['Horror', 'Mystery', 'Thriller']},
#  {'title': 'Hereafter',
#   'domestic': 32746941,
#   'worldwide': 106956330,
#   'distributor': 'Warner Bros.',
#   'opening': 220322,
#   'budget': 50000000,
#   'date': datetime.datetime(2010, 10, 15, 0, 0),
#   'runtime': 129,
#   'widest': 2424,
#   'rating': 'PG-13',
#   'genres': ['Drama', 'Fantasy', 'Romance']},
#  {'title': 'When in Rome',
#   'domestic': 32680633,
#   'worldwide': 43053376,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 12350041,
#   'budget': None,
#   'date': datetime.datetime(2010, 1, 29, 0, 0),
#   'runtime': 91,
#   'widest': 2456,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'Love & Other Drugs',
#   'domestic': 32367005,
#   'worldwide': 102820008,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 9739161,
#   'budget': 30000000,
#   'date': datetime.datetime(2010, 11, 24, 0, 0),
#   'runtime': 112,
#   'widest': 2458,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': "She's Out of My League",
#   'domestic': 32010860,
#   'worldwide': 49779728,
#   'distributor': 'Paramount Pictures',
#   'opening': 9775278,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 3, 12, 0, 0),
#   'runtime': 104,
#   'widest': 2958,
#   'rating': 'R',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'Scott Pilgrim vs. the World',
#   'domestic': 31524275,
#   'worldwide': 47664559,
#   'distributor': 'Universal Pictures',
#   'opening': 10609795,
#   'budget': 60000000,
#   'date': datetime.datetime(2010, 8, 13, 0, 0),
#   'runtime': 112,
#   'widest': 2820,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Comedy', 'Fantasy', 'Romance']},
#  {'title': 'Charlie St. Cloud',
#   'domestic': 31162545,
#   'worldwide': 48190704,
#   'distributor': 'Universal Pictures',
#   'opening': 12381585,
#   'budget': 44000000,
#   'date': datetime.datetime(2010, 7, 30, 0, 0),
#   'runtime': 100,
#   'widest': 2725,
#   'rating': 'PG-13',
#   'genres': ['Drama', 'Fantasy', 'Romance']},
#  {'title': 'Morning Glory',
#   'domestic': 31011732,
#   'worldwide': 60040976,
#   'distributor': 'Paramount Pictures',
#   'opening': 9203266,
#   'budget': 40000000,
#   'date': datetime.datetime(2010, 11, 10, 0, 0),
#   'runtime': 107,
#   'widest': 2544,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'How Do You Know',
#   'domestic': 30212620,
#   'worldwide': 48668907,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 7484696,
#   'budget': 120000000,
#   'date': datetime.datetime(2010, 12, 17, 0, 0),
#   'runtime': 121,
#   'widest': 2483,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Daybreakers',
#   'domestic': 30101577,
#   'worldwide': 51416464,
#   'distributor': 'Lionsgate',
#   'opening': 15146692,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 1, 8, 0, 0),
#   'runtime': 98,
#   'widest': 2523,
#   'rating': 'R',
#   'genres': ['Action',
#    'Adventure',
#    'Fantasy',
#    'Horror',
#    'Sci-Fi',
#    'Thriller']},
#  {'title': 'Nanny McPhee Returns',
#   'domestic': 29011215,
#   'worldwide': 93251121,
#   'distributor': 'Universal Pictures',
#   'opening': 8407685,
#   'budget': 35000000,
#   'date': datetime.datetime(2010, 8, 20, 0, 0),
#   'runtime': 109,
#   'widest': 2798,
#   'rating': 'PG',
#   'genres': ['Comedy', 'Family', 'Fantasy', 'War']},
#  {'title': 'The Switch',
#   'domestic': 27779426,
#   'worldwide': 49830607,
#   'distributor': 'Miramax',
#   'opening': 8436713,
#   'budget': 19000000,
#   'date': datetime.datetime(2010, 8, 20, 0, 0),
#   'runtime': 101,
#   'widest': 2017,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': "Brooklyn's Finest",
#   'domestic': 27163593,
#   'worldwide': 36440201,
#   'distributor': 'Overture Films',
#   'opening': 13350299,
#   'budget': 17000000,
#   'date': datetime.datetime(2010, 3, 5, 0, 0),
#   'runtime': 132,
#   'widest': 1939,
#   'rating': 'R',
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller']},
#  {'title': 'Machete',
#   'domestic': 26593646,
#   'worldwide': 45491656,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 11416164,
#   'budget': 10500000,
#   'date': datetime.datetime(2010, 9, 3, 0, 0),
#   'runtime': 105,
#   'widest': 2678,
#   'rating': 'R',
#   'genres': ['Action', 'Crime', 'Thriller']},
#  {'title': 'Ramona and Beezus',
#   'domestic': 26167002,
#   'worldwide': 27293743,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 7810481,
#   'budget': 15000000,
#   'date': datetime.datetime(2010, 7, 23, 0, 0),
#   'runtime': 104,
#   'widest': 2719,
#   'rating': None,
#   'genres': ['Comedy', 'Drama', 'Family', 'Fantasy']},
#  {'title': 'Leap Year',
#   'domestic': 25918920,
#   'worldwide': 32686500,
#   'distributor': 'Universal Pictures',
#   'opening': 9202815,
#   'budget': 19000000,
#   'date': datetime.datetime(2010, 1, 8, 0, 0),
#   'runtime': 100,
#   'widest': 2512,
#   'rating': 'PG',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'You Again',
#   'domestic': 25702053,
#   'worldwide': 32054369,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 8407513,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 9, 24, 0, 0),
#   'runtime': 105,
#   'widest': 2548,
#   'rating': 'PG',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'Alpha and Omega',
#   'domestic': 25107267,
#   'worldwide': 50507267,
#   'distributor': 'Lionsgate',
#   'opening': 9106906,
#   'budget': None,
#   'date': datetime.datetime(2010, 9, 17, 0, 0),
#   'runtime': 90,
#   'widest': 2625,
#   'rating': 'PG',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Romance']},
#  {'title': 'Piranha 3D',
#   'domestic': 25003155,
#   'worldwide': 83188165,
#   'distributor': 'Dimension Films',
#   'opening': 10106872,
#   'budget': 24000000,
#   'date': datetime.datetime(2010, 8, 20, 0, 0),
#   'runtime': 88,
#   'widest': 2491,
#   'rating': 'R',
#   'genres': ['Comedy', 'Fantasy', 'Horror', 'Romance']},
#  {'title': 'Lottery Ticket',
#   'domestic': 24719879,
#   'worldwide': 24719879,
#   'distributor': 'Warner Bros.',
#   'opening': 10652297,
#   'budget': 17000000,
#   'date': datetime.datetime(2010, 8, 20, 0, 0),
#   'runtime': 99,
#   'widest': 1974,
#   'rating': 'PG-13',
#   'genres': ['Comedy']},
#  {'title': 'The Spy Next Door',
#   'domestic': 24307086,
#   'worldwide': 45236543,
#   'distributor': 'Lionsgate',
#   'opening': 9726056,
#   'budget': 28000000,
#   'date': datetime.datetime(2010, 1, 15, 0, 0),
#   'runtime': 94,
#   'widest': 2924,
#   'rating': 'PG',
#   'genres': ['Action', 'Comedy', 'Family']},
#  {'title': 'From Paris with Love',
#   'domestic': 24077427,
#   'worldwide': 52830951,
#   'distributor': 'Lionsgate',
#   'opening': 8158860,
#   'budget': 52000000,
#   'date': datetime.datetime(2010, 2, 5, 0, 0),
#   'runtime': 92,
#   'widest': 2722,
#   'rating': 'R',
#   'genres': ['Action', 'Crime', 'Thriller']},
#  {'title': 'The Losers',
#   'domestic': 23591432,
#   'worldwide': 29397654,
#   'distributor': 'Warner Bros.',
#   'opening': 9406348,
#   'budget': 25000000,
#   'date': datetime.datetime(2010, 4, 23, 0, 0),
#   'runtime': 97,
#   'widest': 2936,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Crime', 'Mystery', 'Thriller']},
#  {'title': 'Faster',
#   'domestic': 23240020,
#   'worldwide': 35626958,
#   'distributor': 'CBS Films',
#   'opening': 8523153,
#   'budget': 24000000,
#   'date': datetime.datetime(2010, 11, 24, 0, 0),
#   'runtime': 98,
#   'widest': 2470,
#   'rating': 'R',
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller']},
#  {'title': 'Just Wright',
#   'domestic': 21540363,
#   'worldwide': 21584424,
#   'distributor': 'Fox Searchlight Pictures',
#   'opening': 8284989,
#   'budget': None,
#   'date': datetime.datetime(2010, 5, 14, 0, 0),
#   'runtime': 101,
#   'widest': 1831,
#   'rating': 'PG',
#   'genres': ['Comedy', 'Romance', 'Sport']},
#  {'title': 'Skyline',
#   'domestic': 21393620,
#   'worldwide': 66984887,
#   'distributor': 'Universal Pictures',
#   'opening': 11692415,
#   'budget': 10000000,
#   'date': datetime.datetime(2010, 11, 12, 0, 0),
#   'runtime': 92,
#   'widest': 2883,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Sci-Fi', 'Thriller']},
#  {'title': 'The Next Three Days',
#   'domestic': 21148651,
#   'worldwide': 67448651,
#   'distributor': 'Lionsgate',
#   'opening': 6542779,
#   'budget': 30000000,
#   'date': datetime.datetime(2010, 11, 19, 0, 0),
#   'runtime': 133,
#   'widest': 2564,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Crime', 'Drama', 'Romance', 'Thriller']},
#  {'title': 'The Kids Are All Right',
#   'domestic': 20811365,
#   'worldwide': 34705850,
#   'distributor': 'Focus Features',
#   'opening': 491971,
#   'budget': 4000000,
#   'date': datetime.datetime(2010, 7, 9, 0, 0),
#   'runtime': 106,
#   'widest': 994,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Our Family Wedding',
#   'domestic': 20255281,
#   'worldwide': 21409028,
#   'distributor': 'Fox Searchlight Pictures',
#   'opening': 7629862,
#   'budget': None,
#   'date': datetime.datetime(2010, 3, 12, 0, 0),
#   'runtime': 103,
#   'widest': 1609,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'Country Strong',
#   'domestic': 20218921,
#   'worldwide': 20529194,
#   'distributor': 'Screen Gems',
#   'opening': 30452,
#   'budget': 15000000,
#   'date': datetime.datetime(2010, 12, 22, 0, 0),
#   'runtime': 117,
#   'widest': 1441,
#   'rating': 'PG-13',
#   'genres': ['Drama', 'Music']},
#  {'title': 'Oceans',
#   'domestic': 19422319,
#   'worldwide': 83090556,
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'opening': 6058958,
#   'budget': 80000000,
#   'date': datetime.datetime(2010, 4, 22, 0, 0),
#   'runtime': 104,
#   'widest': 1232,
#   'rating': None,
#   'genres': ['Documentary']},
#  {'title': 'Remember Me',
#   'domestic': 19068240,
#   'worldwide': 56032889,
#   'distributor': 'Summit Entertainment',
#   'opening': 8089139,
#   'budget': 16000000,
#   'date': datetime.datetime(2010, 3, 12, 0, 0),
#   'runtime': 113,
#   'widest': 2215,
#   'rating': 'PG-13',
#   'genres': ['Drama', 'Romance']},
#  {'title': '127 Hours',
#   'domestic': 18335230,
#   'worldwide': 60738797,
#   'distributor': 'Fox Searchlight Pictures',
#   'opening': 264851,
#   'budget': 18000000,
#   'date': datetime.datetime(2010, 11, 5, 0, 0),
#   'runtime': 94,
#   'widest': 916,
#   'rating': 'R',
#   'genres': ['Biography', 'Drama']},
#  {'title': 'Going the Distance',
#   'domestic': 17804299,
#   'worldwide': 42059111,
#   'distributor': 'Warner Bros.',
#   'opening': 6884964,
#   'budget': 32000000,
#   'date': datetime.datetime(2010, 9, 3, 0, 0),
#   'runtime': 103,
#   'widest': 3030,
#   'rating': 'R',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'Furry Vengeance',
#   'domestic': 17630465,
#   'worldwide': 36288132,
#   'distributor': 'Summit Entertainment',
#   'opening': 6627564,
#   'budget': 35000000,
#   'date': datetime.datetime(2010, 4, 30, 0, 0),
#   'runtime': 92,
#   'widest': 3002,
#   'rating': 'PG',
#   'genres': ['Comedy', 'Family']},
#  {'title': 'Splice 2010 Re-release',
#   'domestic': 17010170,
#   'worldwide': 27127620,
#   'distributor': 'Warner Bros.',
#   'opening': 7385277,
#   'budget': 30000000,
#   'date': datetime.datetime(2010, 6, 4, 0, 0),
#   'runtime': 104,
#   'widest': 2450,
#   'rating': 'R',
#   'genres': ['Drama', 'Horror', 'Sci-Fi']},
#  {'title': 'The Ghost Writer',
#   'domestic': 15541549,
#   'worldwide': 60331447,
#   'distributor': 'Summit Entertainment',
#   'opening': 183009,
#   'budget': 45000000,
#   'date': datetime.datetime(2010, 2, 19, 0, 0),
#   'runtime': 128,
#   'widest': 819,
#   'rating': 'PG-13',
#   'genres': ['Crime', 'Drama', 'Mystery', 'Thriller']},
#  {'title': 'Youth in Revolt',
#   'domestic': 15281286,
#   'worldwide': 19651093,
#   'distributor': 'Dimension Films',
#   'opening': 6888334,
#   'budget': 18000000,
#   'date': datetime.datetime(2010, 1, 8, 0, 0),
#   'runtime': 90,
#   'widest': 1873,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'My Soul to Take',
#   'domestic': 14744435,
#   'worldwide': 21500813,
#   'distributor': 'Universal Pictures',
#   'opening': 6842220,
#   'budget': 25000000,
#   'date': datetime.datetime(2010, 10, 8, 0, 0),
#   'runtime': 107,
#   'widest': 2572,
#   'rating': 'R',
#   'genres': ['Horror', 'Mystery', 'Thriller']},
#  {'title': 'Repo Men',
#   'domestic': 13794835,
#   'worldwide': 18409891,
#   'distributor': 'Universal Pictures',
#   'opening': 6126170,
#   'budget': 32000000,
#   'date': datetime.datetime(2010, 3, 19, 0, 0),
#   'runtime': 111,
#   'widest': 2521,
#   'rating': 'R',
#   'genres': ['Action', 'Sci-Fi', 'Thriller']},
#  {'title': 'Case 39',
#   'domestic': 13261851,
#   'worldwide': 28190603,
#   'distributor': 'Paramount Vantage',
#   'opening': 5350570,
#   'budget': 26000000,
#   'date': datetime.datetime(2010, 10, 1, 0, 0),
#   'runtime': 109,
#   'widest': 2212,
#   'rating': 'R',
#   'genres': ['Horror', 'Mystery', 'Thriller']},
#  {'title': 'Let Me In',
#   'domestic': 12134935,
#   'worldwide': 27093592,
#   'distributor': 'Overture Films',
#   'opening': 5147479,
#   'budget': 20000000,
#   'date': datetime.datetime(2010, 10, 1, 0, 0),
#   'runtime': 116,
#   'widest': 2042,
#   'rating': 'R',
#   'genres': ['Drama', 'Fantasy', 'Horror', 'Mystery', 'Thriller']},
#  {'title': 'Extraordinary Measures',
#   'domestic': 12068313,
#   'worldwide': 15134293,
#   'distributor': 'CBS Films',
#   'opening': 6012594,
#   'budget': 31000000,
#   'date': datetime.datetime(2010, 1, 22, 0, 0),
#   'runtime': 106,
#   'widest': 2549,
#   'rating': 'PG',
#   'genres': ['Drama']},
#  {'title': 'Avatar 2010 Special Edition',
#   'domestic': 10741486,
#   'worldwide': 44838548,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 4007750,
#   'budget': 237000000,
#   'date': datetime.datetime(2010, 8, 27, 0, 0),
#   'runtime': 162,
#   'widest': 812,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Jonah Hex',
#   'domestic': 10547117,
#   'worldwide': 10903312,
#   'distributor': 'Warner Bros.',
#   'opening': 5379365,
#   'budget': 47000000,
#   'date': datetime.datetime(2010, 6, 18, 0, 0),
#   'runtime': 81,
#   'widest': 2825,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Drama', 'Fantasy', 'Thriller', 'Western']},
#  {'title': 'The Girl with the Dragon Tattoo',
#   'domestic': 10095170,
#   'worldwide': 104414200,
#   'distributor': 'Music Box Films',
#   'opening': 335502,
#   'budget': 13000000,
#   'date': datetime.datetime(2010, 3, 19, 0, 0),
#   'runtime': 152,
#   'widest': 202,
#   'rating': 'R',
#   'genres': ['Crime', 'Drama', 'Mystery', 'Thriller']},
#  {'title': 'Blue Valentine',
#   'domestic': 9706328,
#   'worldwide': 14892418,
#   'distributor': 'The Weinstein Company',
#   'opening': 193728,
#   'budget': 1000000,
#   'date': datetime.datetime(2010, 12, 29, 0, 0),
#   'runtime': 112,
#   'widest': 450,
#   'rating': 'R',
#   'genres': ['Drama', 'Romance']},
#  {'title': 'Fair Game',
#   'domestic': 9540691,
#   'worldwide': 25798915,
#   'distributor': 'Summit Entertainment',
#   'opening': 651082,
#   'budget': 22000000,
#   'date': datetime.datetime(2010, 11, 5, 0, 0),
#   'runtime': 108,
#   'widest': 436,
#   'rating': 'PG-13',
#   'genres': ['Biography', 'Drama', 'Thriller']},
#  {'title': 'Get Low',
#   'domestic': 9176933,
#   'worldwide': 10522511,
#   'distributor': 'Sony Pictures Classics',
#   'opening': 88182,
#   'budget': 7000000,
#   'date': datetime.datetime(2010, 7, 30, 0, 0),
#   'runtime': 103,
#   'widest': 570,
#   'rating': 'PG-13',
#   'genres': ['Drama', 'Mystery']},
#  {'title': 'MacGruber',
#   'domestic': 8525600,
#   'worldwide': 9322895,
#   'distributor': 'Universal Pictures',
#   'opening': 4043495,
#   'budget': 10000000,
#   'date': datetime.datetime(2010, 5, 21, 0, 0),
#   'runtime': 90,
#   'widest': 2551,
#   'rating': 'R',
#   'genres': ['Action', 'Comedy']},
#  {'title': 'The Girl Who Played with Fire',
#   'domestic': 7638241,
#   'worldwide': 67153225,
#   'distributor': 'Music Box Films',
#   'opening': 904998,
#   'budget': None,
#   'date': datetime.datetime(2010, 7, 9, 0, 0),
#   'runtime': 129,
#   'widest': 185,
#   'rating': 'R',
#   'genres': ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller']},
#  {'title': 'Cyrus',
#   'domestic': 7468936,
#   'worldwide': 9933873,
#   'distributor': 'Fox Searchlight Pictures',
#   'opening': 181716,
#   'budget': 7000000,
#   'date': datetime.datetime(2010, 6, 18, 0, 0),
#   'runtime': 91,
#   'widest': 454,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Babies',
#   'domestic': 7320323,
#   'worldwide': 10219306,
#   'distributor': 'Focus Features',
#   'opening': 2160460,
#   'budget': None,
#   'date': datetime.datetime(2010, 5, 7, 0, 0),
#   'runtime': 79,
#   'widest': 543,
#   'rating': 'PG',
#   'genres': ['Documentary']},
#  {'title': 'Conviction 2010 Re-release',
#   'domestic': 6783129,
#   'worldwide': 11104555,
#   'distributor': 'Fox Searchlight Pictures',
#   'opening': 102351,
#   'budget': 12500000,
#   'date': datetime.datetime(2010, 10, 15, 0, 0),
#   'runtime': 107,
#   'widest': 672,
#   'rating': 'R',
#   'genres': ['Biography', 'Crime', 'Drama']},
#  {'title': 'City Island',
#   'domestic': 6671036,
#   'worldwide': 7878856,
#   'distributor': 'Anchor Bay Films',
#   'opening': 32001,
#   'budget': 6000000,
#   'date': datetime.datetime(2010, 3, 19, 0, 0),
#   'runtime': 104,
#   'widest': 269,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama']},
#  {'title': 'The Last Station',
#   'domestic': 6617867,
#   'worldwide': 13550772,
#   'distributor': 'Sony Pictures Classics',
#   'opening': 73723,
#   'budget': 18000000,
#   'date': datetime.datetime(2010, 1, 15, 0, 0),
#   'runtime': 112,
#   'widest': 354,
#   'rating': 'R',
#   'genres': ['Biography', 'Drama', 'Romance']},
#  {'title': "Winter's Bone",
#   'domestic': 6531503,
#   'worldwide': 13796834,
#   'distributor': 'Roadside Attractions',
#   'opening': 84797,
#   'budget': 2000000,
#   'date': datetime.datetime(2010, 6, 11, 0, 0),
#   'runtime': 100,
#   'widest': 141,
#   'rating': 'R',
#   'genres': ['Drama', 'Mystery']},
#  {'title': 'Waiting for Superman',
#   'domestic': 6417135,
#   'worldwide': 6433688,
#   'distributor': 'Paramount Vantage',
#   'opening': 139033,
#   'budget': None,
#   'date': datetime.datetime(2010, 9, 24, 0, 0),
#   'runtime': 111,
#   'widest': 330,
#   'rating': 'PG',
#   'genres': ['Documentary']},
#  {'title': 'The Secret in Their Eyes',
#   'domestic': 6391436,
#   'worldwide': 35079650,
#   'distributor': 'Sony Pictures Classics',
#   'opening': 167866,
#   'budget': None,
#   'date': datetime.datetime(2010, 4, 16, 0, 0),
#   'runtime': 129,
#   'widest': 166,
#   'rating': 'R',
#   'genres': ['Drama', 'Mystery', 'Romance', 'Thriller']},
#  {'title': "It's Kind of a Funny Story",
#   'domestic': 6363628,
#   'worldwide': 6491240,
#   'distributor': 'Focus Features',
#   'opening': 2013406,
#   'budget': 8000000,
#   'date': datetime.datetime(2010, 10, 8, 0, 0),
#   'runtime': 101,
#   'widest': 757,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Sea Rex 3D: Journey to a Prehistoric World',
#   'domestic': 6096582,
#   'worldwide': 16004150,
#   'distributor': '3D Entertainment',
#   'opening': 5000000,
#   'budget': 5000000,
#   'date': datetime.datetime(2010, 5, 28, 0, 0),
#   'runtime': None,
#   'widest': 14,
#   'rating': None,
#   'genres': ['Documentary', 'Short']},
#  {'title': "The Warrior's Way",
#   'domestic': 5666340,
#   'worldwide': 11103434,
#   'distributor': 'Relativity Media',
#   'opening': 3048665,
#   'budget': 42000000,
#   'date': datetime.datetime(2010, 12, 3, 0, 0),
#   'runtime': 100,
#   'widest': 1622,
#   'rating': 'R',
#   'genres': ['Action', 'Fantasy', 'Western']},
#  {'title': "The Girl Who Kicked the Hornet's Nest",
#   'domestic': 5190196,
#   'worldwide': 44276335,
#   'distributor': 'Music Box Films',
#   'opening': 881737,
#   'budget': None,
#   'date': datetime.datetime(2010, 10, 29, 0, 0),
#   'runtime': 147,
#   'widest': 208,
#   'rating': 'R',
#   'genres': ['Crime', 'Drama', 'Thriller']},
#  {'title': 'I Am Love',
#   'domestic': 5005465,
#   'worldwide': 12014663,
#   'distributor': 'Magnolia Pictures',
#   'opening': 121504,
#   'budget': None,
#   'date': datetime.datetime(2010, 6, 18, 0, 0),
#   'runtime': None,
#   'widest': 166,
#   'rating': 'R',
#   'genres': ['Drama', 'Romance']},
#  {'title': "Mao's Last Dancer",
#   'domestic': 4817770,
#   'worldwide': 23914731,
#   'distributor': 'The Samuel Goldwyn Company',
#   'opening': 199657,
#   'budget': None,
#   'date': datetime.datetime(2010, 8, 20, 0, 0),
#   'runtime': 117,
#   'widest': 137,
#   'rating': 'PG',
#   'genres': ['Biography', 'Drama', 'Music', 'Romance']},
#  {'title': 'Solitary Man',
#   'domestic': 4360548,
#   'worldwide': 5615390,
#   'distributor': 'Anchor Bay Films',
#   'opening': 94936,
#   'budget': 15000000,
#   'date': datetime.datetime(2010, 5, 21, 0, 0),
#   'runtime': 90,
#   'widest': 177,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Inside Job',
#   'domestic': 4312735,
# ...
#   'genres': ['Action', 'Drama', 'Sci-Fi']},
#  {'title': 'The Railway Man',
#   'domestic': 4438438,
#   'worldwide': 24174885,
#   'distributor': 'The Weinstein Company',
#   'opening': 61845,
#   'budget': None,
#   'date': datetime.datetime(2014, 4, 11, 0, 0),
#   'runtime': 116,
#   'widest': 600,
#   'rating': 'R',
#   'genres': ['Biography', 'Drama', 'Romance', 'War']},
#  {'title': 'Dear White People',
#   'domestic': 4404154,
#   'worldwide': 4633961,
#   'distributor': 'Roadside Attractions',
#   'opening': 347959,
#   'budget': None,
#   'date': datetime.datetime(2014, 10, 17, 0, 0),
#   'runtime': 108,
#   'widest': 393,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'The Lunchbox 2013 Re-release',
#   'domestic': 4235151,
#   'worldwide': 11621581,
#   'distributor': 'Sony Pictures Classics',
#   'opening': 44542,
#   'budget': None,
#   'date': datetime.datetime(2014, 2, 28, 0, 0),
#   'runtime': 104,
#   'widest': 165,
#   'rating': 'PG',
#   'genres': ['Drama', 'Romance']},
#  {'title': 'My Old Lady',
#   'domestic': 4013786,
#   'worldwide': 10606667,
#   'distributor': 'Cohen Media Group',
#   'opening': 124680,
#   'budget': None,
#   'date': datetime.datetime(2014, 9, 10, 0, 0),
#   'runtime': 107,
#   'widest': 273,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Mr. Turner',
#   'domestic': 3958500,
#   'worldwide': 22179785,
#   'distributor': 'Sony Pictures Classics',
#   'opening': 109000,
#   'budget': None,
#   'date': datetime.datetime(2014, 12, 19, 0, 0),
#   'runtime': 150,
#   'widest': 120,
#   'rating': 'R',
#   'genres': ['Biography', 'Drama', 'History']},
#  {'title': 'Ida',
#   'domestic': 3827060,
#   'worldwide': 11156836,
#   'distributor': 'Music Box Films',
#   'opening': 55438,
#   'budget': None,
#   'date': datetime.datetime(2014, 5, 2, 0, 0),
#   'runtime': 82,
#   'widest': 137,
#   'rating': 'PG-13',
#   'genres': ['Drama']},
#  {'title': 'Fading Gigolo',
#   'domestic': 3769873,
#   'worldwide': 22706304,
#   'distributor': 'Millennium Entertainment',
#   'opening': 180801,
#   'budget': None,
#   'date': datetime.datetime(2014, 4, 18, 0, 0),
#   'runtime': 90,
#   'widest': 356,
#   'rating': 'R',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'Calvary',
#   'domestic': 3600006,
#   'worldwide': 16887741,
#   'distributor': 'Fox Searchlight Pictures',
#   'opening': 74149,
#   'budget': None,
#   'date': datetime.datetime(2014, 8, 1, 0, 0),
#   'runtime': 102,
#   'widest': 322,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Mystery']},
#  {'title': 'Wish I Was Here',
#   'domestic': 3591299,
#   'worldwide': 5670776,
#   'distributor': 'Focus Features',
#   'opening': 484401,
#   'budget': None,
#   'date': datetime.datetime(2014, 7, 18, 0, 0),
#   'runtime': 106,
#   'widest': 753,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama']},
#  {'title': 'Ghostbusters 30th Anniversary Release',
#   'domestic': 3580343,
#   'worldwide': 3580343,
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'opening': 1756513,
#   'budget': 30000000,
#   'date': datetime.datetime(2014, 8, 29, 0, 0),
#   'runtime': 105,
#   'widest': 784,
#   'rating': None,
#   'genres': ['Action', 'Comedy', 'Fantasy', 'Sci-Fi']},
#  {'title': 'Mommy',
#   'domestic': 3494070,
#   'worldwide': 13156856,
#   'distributor': 'Roadside Attractions',
#   'opening': 473882,
#   'budget': None,
#   'date': datetime.datetime(2014, 9, 19, 0, 0),
#   'runtime': 139,
#   'widest': 83,
#   'rating': 'R',
#   'genres': ['Drama']},
#  {'title': 'What If',
#   'domestic': 3493000,
#   'worldwide': 8526288,
#   'distributor': 'CBS Films',
#   'opening': 133898,
#   'budget': None,
#   'date': datetime.datetime(2014, 8, 8, 0, 0),
#   'runtime': 98,
#   'widest': 787,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Romance']},
#  {'title': 'The Grand Seduction',
#   'domestic': 3430018,
#   'worldwide': 4292517,
#   'distributor': 'Entertainment One',
#   'opening': 41433,
#   'budget': None,
#   'date': datetime.datetime(2014, 5, 23, 0, 0),
#   'runtime': 113,
#   'widest': 124,
#   'rating': 'PG-13',
#   'genres': ['Comedy']},
#  {'title': 'Veronica Mars',
#   'domestic': 3322127,
#   'worldwide': 3485383,
#   'distributor': 'Warner Bros.',
#   'opening': 1988351,
#   'budget': 6000000,
#   'date': datetime.datetime(2014, 3, 14, 0, 0),
#   'runtime': 107,
#   'widest': 347,
#   'rating': 'PG-13',
#   'genres': ['Crime', 'Drama', 'Mystery', 'Thriller']},
#  {'title': 'Before I Go to Sleep',
#   'domestic': 3242457,
#   'worldwide': 17669776,
#   'distributor': 'Clarius Entertainment',
#   'opening': 1843347,
#   'budget': None,
#   'date': datetime.datetime(2014, 10, 31, 0, 0),
#   'runtime': 92,
#   'widest': 1902,
#   'rating': 'R',
#   'genres': ['Drama', 'Mystery', 'Thriller']},
#  {'title': 'Rosewater',
#   'domestic': 3128941,
#   'worldwide': 3171593,
#   'distributor': 'Open Road Films (II)',
#   'opening': 1154303,
#   'budget': None,
#   'date': datetime.datetime(2014, 11, 14, 0, 0),
#   'runtime': 103,
#   'widest': 371,
#   'rating': 'R',
#   'genres': ['Biography', 'Drama']},
#  {'title': 'Obvious Child',
#   'domestic': 3123963,
#   'worldwide': 3325417,
#   'distributor': 'A24',
#   'opening': 77315,
#   'budget': None,
#   'date': datetime.datetime(2014, 6, 6, 0, 0),
#   'runtime': 84,
#   'widest': 202,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'The Trip to Italy',
#   'domestic': 2880537,
#   'worldwide': 6089109,
#   'distributor': 'IFC Films',
#   'opening': 71712,
#   'budget': None,
#   'date': datetime.datetime(2014, 8, 15, 0, 0),
#   'runtime': 108,
#   'widest': 199,
#   'rating': None,
#   'genres': ['Comedy', 'Drama']},
#  {'title': 'The Identical',
#   'domestic': 2827666,
#   'worldwide': 2840991,
#   'distributor': 'Freestyle Releasing',
#   'opening': 1587137,
#   'budget': None,
#   'date': datetime.datetime(2014, 9, 5, 0, 0),
#   'runtime': 107,
#   'widest': 1956,
#   'rating': 'PG',
#   'genres': ['Drama', 'Music']},
#  {'title': 'The Fluffy Movie: Unity Through Laughter',
#   'domestic': 2827393,
#   'worldwide': 2827393,
#   'distributor': 'Open Road Films (II)',
#   'opening': 1311446,
#   'budget': None,
#   'date': datetime.datetime(2014, 7, 25, 0, 0),
#   'runtime': 101,
#   'widest': 432,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Documentary']},
#  {'title': 'Citizenfour',
#   'domestic': 2800870,
#   'worldwide': 3780692,
#   'distributor': 'RADiUS-TWC',
#   'opening': 126321,
#   'budget': None,
#   'date': datetime.datetime(2014, 10, 24, 0, 0),
#   'runtime': 114,
#   'widest': 105,
#   'rating': 'R',
#   'genres': ['Biography', 'Documentary', 'History']},
#  {'title': "Kirk Cameron's Saving Christmas",
#   'domestic': 2783970,
#   'worldwide': 2783970,
#   'distributor': 'The Samuel Goldwyn Company',
#   'opening': 992087,
#   'budget': None,
#   'date': datetime.datetime(2014, 11, 14, 0, 0),
#   'runtime': 79,
#   'widest': 410,
#   'rating': 'PG',
#   'genres': ['Comedy', 'Family']},
#  {'title': 'The Pyramid',
#   'domestic': 2756333,
#   'worldwide': 16861137,
#   'distributor': 'Twentieth Century Fox',
#   'opening': 1369935,
#   'budget': None,
#   'date': datetime.datetime(2014, 12, 5, 0, 0),
#   'runtime': 89,
#   'widest': 685,
#   'rating': 'R',
#   'genres': ['Horror', 'Mystery', 'Thriller']},
#  {'title': 'The Good Lie',
#   'domestic': 2722209,
#   'worldwide': 3396345,
#   'distributor': 'Warner Bros.',
#   'opening': 841422,
#   'budget': None,
#   'date': datetime.datetime(2014, 10, 3, 0, 0),
#   'runtime': 110,
#   'widest': 461,
#   'rating': 'PG-13',
#   'genres': ['Biography', 'Drama']},
#  {'title': 'The Raid 2',
#   'domestic': 2627209,
#   'worldwide': 6566916,
#   'distributor': 'Sony Pictures Classics',
#   'opening': 165292,
#   'budget': None,
#   'date': datetime.datetime(2014, 3, 28, 0, 0),
#   'runtime': 150,
#   'widest': 954,
#   'rating': 'R',
#   'genres': ['Action', 'Crime', 'Thriller']},
#  {'title': 'Under the Skin',
#   'domestic': 2614251,
#   'worldwide': 5735963,
#   'distributor': 'A24',
#   'opening': 133154,
#   'budget': 13300000,
#   'date': datetime.datetime(2014, 4, 4, 0, 0),
#   'runtime': 108,
#   'widest': 176,
#   'rating': 'R',
#   'genres': ['Drama', 'Horror', 'Sci-Fi', 'Thriller']},
#  {'title': 'The Admiral: Roaring Currents',
#   'domestic': 2589811,
#   'worldwide': 138342258,
#   'distributor': 'CJ Entertainment',
#   'opening': 51431,
#   'budget': None,
#   'date': datetime.datetime(2014, 8, 8, 0, 0),
#   'runtime': 128,
#   'widest': 45,
#   'rating': None,
#   'genres': ['Action', 'Drama', 'History', 'War']},
#  {'title': 'Dragon Ball Z: Battle of Gods',
#   'domestic': 2553002,
#   'worldwide': 50461371,
#   'distributor': 'Screenvision',
#   'opening': 296414,
#   'budget': None,
#   'date': datetime.datetime(2014, 8, 5, 0, 0),
#   'runtime': 85,
#   'widest': 692,
#   'rating': None,
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Sci-Fi']},
#  {'title': 'Bang Bang',
#   'domestic': 2546172,
#   'worldwide': 42045981,
#   'distributor': 'FIP',
#   'opening': 1278690,
#   'budget': None,
#   'date': datetime.datetime(2014, 10, 2, 0, 0),
#   'runtime': 153,
#   'widest': 271,
#   'rating': None,
#   'genres': ['Action',
#    'Adventure',
#    'Comedy',
#    'Musical',
#    'Romance',
#    'Thriller']},
#  {'title': 'Kick',
#   'domestic': 2472695,
#   'worldwide': 43996483,
#   'distributor': 'UTV Motion Pictures',
#   'opening': 1071373,
#   'budget': None,
#   'date': datetime.datetime(2014, 7, 25, 0, 0),
#   'runtime': 146,
#   'widest': 180,
#   'rating': None,
#   'genres': ['Action', 'Comedy', 'Crime', 'Thriller']},
#  {'title': 'Kill the Messenger',
#   'domestic': 2450846,
#   'worldwide': 5218973,
#   'distributor': 'Focus Features',
#   'opening': 941809,
#   'budget': None,
#   'date': datetime.datetime(2014, 10, 10, 0, 0),
#   'runtime': 112,
#   'widest': 427,
#   'rating': 'R',
#   'genres': ['Biography', 'Crime', 'Drama', 'Mystery', 'Thriller']},
#  {'title': 'The Homesman',
#   'domestic': 2429989,
#   'worldwide': 3819421,
#   'distributor': 'Saban Films',
#   'opening': 45433,
#   'budget': None,
#   'date': datetime.datetime(2014, 11, 14, 0, 0),
#   'runtime': 122,
#   'widest': 222,
#   'rating': 'R',
#   'genres': ['Drama', 'Western']},
#  {'title': 'Ode to My Father',
#   'domestic': 2300121,
#   'worldwide': 99085291,
#   'distributor': 'CJ Entertainment',
#   'opening': 33880,
#   'budget': None,
#   'date': datetime.datetime(2014, 12, 25, 0, 0),
#   'runtime': 126,
#   'widest': 38,
#   'rating': None,
#   'genres': ['Drama', 'War']},
#  {'title': 'Love Is Strange 2014 Re-release',
#   'domestic': 2262223,
#   'worldwide': 2979739,
#   'distributor': 'Sony Pictures Classics',
#   'opening': 117276,
#   'budget': None,
#   'date': datetime.datetime(2014, 8, 22, 0, 0),
#   'runtime': 94,
#   'widest': 138,
#   'rating': 'R',
#   'genres': ['Drama', 'Romance']},
#  {'title': '2 States',
#   'domestic': 2238174,
#   'worldwide': 22386518,
#   'distributor': 'UTV Motion Pictures',
#   'opening': 1073898,
#   'budget': None,
#   'date': datetime.datetime(2014, 4, 18, 0, 0),
#   'runtime': 149,
#   'widest': 137,
#   'rating': None,
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Le Week-end',
#   'domestic': 2225098,
#   'worldwide': 8652213,
#   'distributor': 'Music Box Films',
#   'opening': 43608,
#   'budget': None,
#   'date': datetime.datetime(2014, 3, 14, 0, 0),
#   'runtime': 93,
#   'widest': 157,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Anchorman 2: The Legend Continues R-Rated Extended Cut',
#   'domestic': 2184339,
#   'worldwide': 2185255,
#   'distributor': 'Paramount Pictures',
#   'opening': 1358833,
#   'budget': 50000000,
#   'date': datetime.datetime(2014, 2, 28, 0, 0),
#   'runtime': 119,
#   'widest': 1317,
#   'rating': 'PG-13',
#   'genres': ['Comedy']},
#  {'title': 'The Oscar Nominated Short Films 2014: Live Action',
#   'domestic': 2171849,
#   'worldwide': 2171849,
#   'distributor': 'Shorts International',
#   'opening': 329505,
#   'budget': None,
#   'date': datetime.datetime(2014, 1, 31, 0, 0),
#   'runtime': 111,
#   'widest': 167,
#   'rating': None,
#   'genres': ['Drama']},
#  {'title': 'Words and Pictures',
#   'domestic': 2171257,
#   'worldwide': 3438874,
#   'distributor': 'Roadside Attractions',
#   'opening': 87879,
#   'budget': None,
#   'date': datetime.datetime(2014, 5, 23, 0, 0),
#   'runtime': 111,
#   'widest': 216,
#   'rating': 'PG-13',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'Gloria',
#   'domestic': 2107925,
#   'worldwide': 6461559,
#   'distributor': 'Roadside Attractions',
#   'opening': 56454,
#   'budget': None,
#   'date': datetime.datetime(2014, 1, 24, 0, 0),
#   'runtime': 110,
#   'widest': 110,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Romance']},
#  {'title': 'The Immigrant',
#   'domestic': 2025328,
#   'worldwide': 5952884,
#   'distributor': 'The Weinstein Company',
#   'opening': 44064,
#   'budget': None,
#   'date': datetime.datetime(2014, 5, 16, 0, 0),
#   'runtime': None,
#   'widest': 150,
#   'rating': 'R',
#   'genres': ['Drama', 'Romance']},
#  {'title': 'Only Lovers Left Alive',
#   'domestic': 1879534,
#   'worldwide': 7609187,
#   'distributor': 'Sony Pictures Classics',
#   'opening': 87989,
#   'budget': 7000000,
#   'date': datetime.datetime(2014, 4, 11, 0, 0),
#   'runtime': 123,
#   'widest': 95,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Fantasy', 'Horror', 'Romance']},
#  {'title': 'Tusk',
#   'domestic': 1826705,
#   'worldwide': 1882074,
#   'distributor': 'A24',
#   'opening': 846831,
#   'budget': None,
#   'date': datetime.datetime(2014, 9, 19, 0, 0),
#   'runtime': 102,
#   'widest': 602,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama', 'Horror', 'Thriller']},
#  {'title': "Tim's Vermeer",
#   'domestic': 1671377,
#   'worldwide': 1686917,
#   'distributor': 'Sony Pictures Classics',
#   'opening': 49777,
#   'budget': None,
#   'date': datetime.datetime(2014, 1, 31, 0, 0),
#   'runtime': 80,
#   'widest': 129,
#   'rating': 'PG-13',
#   'genres': ['Documentary', 'History']},
#  {'title': 'Persecuted',
#   'domestic': 1558836,
#   'worldwide': 1558836,
#   'distributor': 'Millennium Entertainment',
#   'opening': 851391,
#   'budget': None,
#   'date': datetime.datetime(2014, 7, 18, 0, 0),
#   'runtime': 91,
#   'widest': 736,
#   'rating': 'PG-13',
#   'genres': ['Action', 'Drama', 'Mystery', 'Thriller']},
#  {'title': 'Awake: The Life of Yogananda',
#   'domestic': 1539680,
#   'worldwide': 1891918,
#   'distributor': 'Counterpoint Films & Self-Realization Fellowship',
#   'opening': 18885,
#   'budget': None,
#   'date': datetime.datetime(2014, 10, 10, 0, 0),
#   'runtime': 87,
#   'widest': 21,
#   'rating': 'PG',
#   'genres': ['Documentary']},
#  {'title': 'Fed Up',
#   'domestic': 1538899,
#   'worldwide': 1546229,
#   'distributor': 'RADiUS-TWC',
#   'opening': 126028,
#   'budget': None,
#   'date': datetime.datetime(2014, 5, 9, 0, 0),
#   'runtime': 92,
#   'widest': 104,
#   'rating': 'PG',
#   'genres': ['Documentary']},
#  {'title': 'Finding Vivian Maier',
#   'domestic': 1514782,
#   'worldwide': 2384584,
#   'distributor': 'IFC Films',
#   'opening': 63600,
#   'budget': None,
#   'date': datetime.datetime(2014, 3, 28, 0, 0),
#   'runtime': 83,
#   'widest': 97,
#   'rating': None,
#   'genres': ['Biography', 'Documentary', 'Mystery']},
#  {'title': 'Pride',
#   'domestic': 1446634,
#   'worldwide': 16699029,
#   'distributor': 'CBS Films',
#   'opening': 100040,
#   'budget': None,
#   'date': datetime.datetime(2014, 9, 26, 0, 0),
#   'runtime': 119,
#   'widest': 124,
#   'rating': 'R',
#   'genres': ['Biography', 'Comedy', 'Drama', 'History', 'Romance']},
#  {'title': 'Two Days, One Night',
#   'domestic': 1436243,
#   'worldwide': 9016922,
#   'distributor': 'IFC Films',
#   'opening': 30700,
#   'budget': None,
#   'date': datetime.datetime(2014, 12, 24, 0, 0),
#   'runtime': 95,
#   'widest': 120,
#   'rating': 'PG-13',
#   'genres': ['Drama']},
#  {'title': 'Locke',
#   'domestic': 1375769,
#   'worldwide': 5090608,
#   'distributor': 'A24',
#   'opening': 81006,
#   'budget': None,
#   'date': datetime.datetime(2014, 4, 25, 0, 0),
#   'runtime': 85,
#   'widest': 121,
#   'rating': 'R',
#   'genres': ['Drama']},
#  {'title': 'Gimme Shelter',
#   'domestic': 1359910,
#   'worldwide': 1362018,
#   'distributor': 'Roadside Attractions',
#   'opening': 689070,
#   'budget': None,
#   'date': datetime.datetime(2014, 1, 24, 0, 0),
#   'runtime': None,
#   'widest': 385,
#   'rating': 'PG-13',
#   'genres': ['Drama']},
#  {'title': 'Force Majeure',
#   'domestic': 1359497,
#   'worldwide': 4094339,
#   'distributor': 'Magnolia Pictures',
#   'opening': 23309,
#   'budget': None,
#   'date': datetime.datetime(2014, 10, 24, 0, 0),
#   'runtime': None,
#   'widest': 68,
#   'rating': 'R',
#   'genres': ['Comedy', 'Drama']},
#  ...]

# %% [markdown]
# ## Simple EDA and Baseline Model
#
# ### Create a DataFrame (df)

# %%
df = pd.DataFrame(movies_list)
df.set_index('title', inplace=True)

df
# Out:
#                                                domestic   worldwide  \
# title
# Toy Story 3                                   415004880  1066969703
# Alice in Wonderland                           334191110  1025467110
# Iron Man 2                                    312433331   623933331
# The Twilight Saga: Eclipse                    300531751   698491347
# Harry Potter and the Deathly Hallows: Part 1  295983305   976536918
# ...                                                 ...         ...
# Red Joan                                        1579730    10647493
# After the Wedding                               1574258     2790019
# Extreme Job                                     1565885   119932733
# The Kid                                         1508593     1553483
# El Chicano                                      1400603     1404646
#
#                                                                       distributor  \
# title
# Toy Story 3                                   Walt Disney Studios Motion Pictures
# Alice in Wonderland                           Walt Disney Studios Motion Pictures
# Iron Man 2                                                     Paramount Pictures
# The Twilight Saga: Eclipse                                   Summit Entertainment
# Harry Potter and the Deathly Hallows: Part 1                         Warner Bros.
# ...                                                                           ...
# Red Joan                                                                IFC Films
# After the Wedding                                          Sony Pictures Classics
# Extreme Job                                                      CJ Entertainment
# The Kid                                                                 Lionsgate
# El Chicano                                               Briarcliff Entertainment
#
#                                                   opening       budget  \
# title
# Toy Story 3                                   110307189.0  200000000.0
# Alice in Wonderland                           116101023.0  200000000.0
# Iron Man 2                                    128122480.0  200000000.0
# The Twilight Saga: Eclipse                     64832191.0   68000000.0
# Harry Potter and the Deathly Hallows: Part 1  125017372.0          NaN
# ...                                                   ...          ...
# Red Joan                                          38949.0          NaN
# After the Wedding                                 50264.0          NaN
# Extreme Job                                       42587.0          NaN
# The Kid                                          514286.0          NaN
# El Chicano                                       700261.0          NaN
#
#                                                    date  runtime  widest  \
# title
# Toy Story 3                                  2010-06-18    103.0  4028.0
# Alice in Wonderland                          2010-03-05    108.0  3739.0
# Iron Man 2                                   2010-05-07    124.0  4390.0
# The Twilight Saga: Eclipse                   2010-06-30    124.0  4468.0
# Harry Potter and the Deathly Hallows: Part 1 2010-11-19    146.0  4125.0
# ...                                                 ...      ...     ...
# Red Joan                                     2019-04-19    101.0   195.0
# After the Wedding                            2019-08-09    112.0   428.0
# Extreme Job                                  2019-01-25    111.0    26.0
# The Kid                                      2019-03-08    100.0   268.0
# El Chicano                                   2019-05-03    144.0   605.0
#
#                                              rating  \
# title
# Toy Story 3                                    None
# Alice in Wonderland                              PG
# Iron Man 2                                    PG-13
# The Twilight Saga: Eclipse                    PG-13
# Harry Potter and the Deathly Hallows: Part 1  PG-13
# ...                                             ...
# Red Joan                                          R
# After the Wedding                             PG-13
# Extreme Job                                    None
# The Kid                                           R
# El Chicano                                        R
#
#                                                                                          genres
# title
# Toy Story 3                                     [Adventure, Animation, Comedy, Family, Fantasy]
# Alice in Wonderland                                                [Adventure, Family, Fantasy]
# Iron Man 2                                                          [Action, Adventure, Sci-Fi]
# The Twilight Saga: Eclipse                    [Action, Adventure, Drama, Fantasy, Romance, T...
# Harry Potter and the Deathly Hallows: Part 1              [Adventure, Family, Fantasy, Mystery]
# ...                                                                                         ...
# Red Joan                                                   [Biography, Drama, History, Romance]
# After the Wedding                                                                       [Drama]
# Extreme Job                                                             [Action, Comedy, Crime]
# The Kid                                                             [Biography, Drama, Western]
# El Chicano                                                     [Action, Crime, Drama, Thriller]
#
# [2000 rows x 10 columns]

# %%
# Necessary imports
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_formats = ['svg']  # or svg
# %matplotlib inline

sns.set(context='notebook', style='whitegrid', font_scale=1.2)

# %%
df.dtypes
# Out:
# domestic                int64
# worldwide               int64
# distributor            object
# opening               float64
# budget                float64
# date           datetime64[ns]
# runtime               float64
# widest                float64
# rating                 object
# genres                 object
# dtype: object

# %%
## Examine the columns, look at missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, Toy Story 3 to El Chicano
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   domestic     2000 non-null   int64
#  1   worldwide    2000 non-null   int64
#  2   distributor  1999 non-null   object
#  3   opening      1981 non-null   float64
#  4   budget       1187 non-null   float64
#  5   date         2000 non-null   datetime64[ns]
#  6   runtime      1947 non-null   float64
#  7   widest       1998 non-null   float64
#  8   rating       1847 non-null   object
#  9   genres       1996 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(3)
# memory usage: 171.9+ KB

# %% [markdown]
# ### Remove/drop null-values

# %%
df = df.dropna()

# %%
df.to_csv('data/movies')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1151 entries, Alice in Wonderland to The Wizard of Oz 2019 Re-release
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   domestic     1151 non-null   int64
#  1   worldwide    1151 non-null   int64
#  2   distributor  1151 non-null   object
#  3   opening      1151 non-null   float64
#  4   budget       1151 non-null   float64
#  5   date         1151 non-null   datetime64[ns]
#  6   runtime      1151 non-null   float64
#  7   widest       1151 non-null   float64
#  8   rating       1151 non-null   object
#  9   genres       1151 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(3)
# memory usage: 98.9+ KB

# %% [markdown]
# ### Create quantitative DataFrame (df_num)
#
# - Domestic Release
# - Worldwide Release
# - Opening
# - Budget
# - Runtime
# - Widest Release

# %%
df_num= df.loc[:,["worldwide", "domestic", "opening", "budget", "runtime", "widest"]]

# %%
df_num.head()
# Out:
#                              worldwide   domestic      opening       budget  \
# title
# Alice in Wonderland         1025467110  334191110  116101023.0  200000000.0
# Iron Man 2                   623933331  312433331  128122480.0  200000000.0
# The Twilight Saga: Eclipse   698491347  300531751   64832191.0   68000000.0
# Inception                    826137188  292576195   62785337.0  160000000.0
# Despicable Me                543113985  251513985   56397125.0   69000000.0
#
#                             runtime  widest
# title
# Alice in Wonderland           108.0  3739.0
# Iron Man 2                    124.0  4390.0
# The Twilight Saga: Eclipse    124.0  4468.0
# Inception                     148.0  3792.0
# Despicable Me                  95.0  3602.0

# %%
df_num.to_csv('data/movies_num')

# %% [markdown]
# ### Create Qualitative DataFrame (df_cat)
#
# We use dummy variables function for this.
#
# - Distrubutor
# - MPAA Rating
# - Genres
# - Release Date
#
# Distributor

# %%
#df_cat = df

# %%
dist_quantity = df['distributor'].value_counts()
dist_quantity
# Out:
# Warner Bros.                             159
# Universal Pictures                       151
# Twentieth Century Fox                    132
# Sony Pictures Entertainment (SPE)         95
# Paramount Pictures                        94
# Lionsgate                                 86
# Walt Disney Studios Motion Pictures       81
# Screen Gems                               35
# Focus Features                            29
# Relativity Media                          28
# Open Road Films (II)                      22
# STX Entertainment                         22
# Sony Pictures Classics                    21
# Fox Searchlight Pictures                  20
# TriStar Pictures                          20
# The Weinstein Company                     20
# Summit Entertainment                      13
# Roadside Attractions                      11
# DreamWorks                                10
# CBS Films                                 10
# FilmDistrict                              10
# Dimension Films                            8
# A24                                        8
# BH Tilt                                    5
# Metro-Goldwyn-Mayer (MGM)                  5
# Broad Green Pictures                       4
# Entertainment Studios Motion Pictures      4
# Overture Films                             4
# United Artists Releasing                   4
# Freestyle Releasing                        3
# Affirm Films                               3
# Anchor Bay Films                           2
# Studio 8                                   2
# The Samuel Goldwyn Company                 2
# Bleecker Street Media                      2
# Orion Pictures                             2
# Aviron Pictures                            2
# Clarius Entertainment                      1
# Pantelion Films                            1
# Vivendi Entertainment                      1
# Quality Flix                               1
# EuropaCorp                                 1
# IFC Films                                  1
# Neon                                       1
# Newmarket Films                            1
# Miramax                                    1
# Cinelou Films                              1
# Rocky Mountain Pictures                    1
# Quaker Media                               1
# Annapurna Pictures                         1
# Apparition                                 1
# Music Box Films                            1
# Pure Flix Entertainment                    1
# FUNimation Entertainment                   1
# OTL Releasing                              1
# ATO Pictures                               1
# Picturehouse (II)                          1
# Paramount Vantage                          1
# Fathom Events                              1
# Name: distributor, dtype: int64

# %% [markdown]
# Let's group distributor by less than 9 movies so we can avoid the oulies of the smaller distrubutors.
#
# _Note:_ Seems to be a lot a distrubutor with few films. This outlier remember we are using movie data from 2010-2019 so during these years video streaming services like Netflix got very popular and people began to spend less time and movie at movie theather and more time and movie at streaming services. This is something we can analize in a second part of the current project. let's keep focused on this part for now.

# %%
dist_quantity =  df['distributor'].value_counts()
dist_quantity[dist_quantity <= 8]

other_dist = list(dist_quantity[dist_quantity<=8].index)

# %%
df_distributor = df.copy()
df_distributor['distributor'] = df['distributor'].replace(other_dist, 'Other')

# %%
df_distributor['distributor'].value_counts()
# Out:
# Warner Bros.                           159
# Universal Pictures                     151
# Twentieth Century Fox                  132
# Sony Pictures Entertainment (SPE)       95
# Paramount Pictures                      94
# Lionsgate                               86
# Other                                   82
# Walt Disney Studios Motion Pictures     81
# Screen Gems                             35
# Focus Features                          29
# Relativity Media                        28
# STX Entertainment                       22
# Open Road Films (II)                    22
# Sony Pictures Classics                  21
# TriStar Pictures                        20
# The Weinstein Company                   20
# Fox Searchlight Pictures                20
# Summit Entertainment                    13
# Roadside Attractions                    11
# DreamWorks                              10
# CBS Films                               10
# FilmDistrict                            10
# Name: distributor, dtype: int64

# %%
df_distributor = pd.get_dummies(df['distributor'], drop_first=True)
df_distributor.head()
# Out:
#                             ATO Pictures  Affirm Films  Anchor Bay Films  \
# title
# Alice in Wonderland                    0             0                 0
# Iron Man 2                             0             0                 0
# The Twilight Saga: Eclipse             0             0                 0
# Inception                              0             0                 0
# Despicable Me                          0             0                 0
#
#                             Annapurna Pictures  Apparition  Aviron Pictures  \
# title
# Alice in Wonderland                          0           0                0
# Iron Man 2                                   0           0                0
# The Twilight Saga: Eclipse                   0           0                0
# Inception                                    0           0                0
# Despicable Me                                0           0                0
#
#                             BH Tilt  Bleecker Street Media  \
# title
# Alice in Wonderland               0                      0
# Iron Man 2                        0                      0
# The Twilight Saga: Eclipse        0                      0
# Inception                         0                      0
# Despicable Me                     0                      0
#
#                             Broad Green Pictures  CBS Films  ...  \
# title                                                        ...
# Alice in Wonderland                            0          0  ...
# Iron Man 2                                     0          0  ...
# The Twilight Saga: Eclipse                     0          0  ...
# Inception                                      0          0  ...
# Despicable Me                                  0          0  ...
#
#                             Summit Entertainment  The Samuel Goldwyn Company  \
# title
# Alice in Wonderland                            0                           0
# Iron Man 2                                     0                           0
# The Twilight Saga: Eclipse                     1                           0
# Inception                                      0                           0
# Despicable Me                                  0                           0
#
#                             The Weinstein Company  TriStar Pictures  \
# title
# Alice in Wonderland                             0                 0
# Iron Man 2                                      0                 0
# The Twilight Saga: Eclipse                      0                 0
# Inception                                       0                 0
# Despicable Me                                   0                 0
#
#                             Twentieth Century Fox  United Artists Releasing  \
# title
# Alice in Wonderland                             0                         0
# Iron Man 2                                      0                         0
# The Twilight Saga: Eclipse                      0                         0
# Inception                                       0                         0
# Despicable Me                                   0                         0
#
#                             Universal Pictures  Vivendi Entertainment  \
# title
# Alice in Wonderland                          0                      0
# Iron Man 2                                   0                      0
# The Twilight Saga: Eclipse                   0                      0
# Inception                                    0                      0
# Despicable Me                                1                      0
#
#                             Walt Disney Studios Motion Pictures  Warner Bros.
# title
# Alice in Wonderland                                           1             0
# Iron Man 2                                                    0             0
# The Twilight Saga: Eclipse                                    0             0
# Inception                                                     0             1
# Despicable Me                                                 0             0
#
# [5 rows x 58 columns]

# %%
df_distributor.to_csv('data/distributor')

# %% [markdown]
# MPAA Rating

# %%
df['rating'].unique()
# Out:
# array(['PG', 'PG-13', 'R', 'G'], dtype=object)

# %%
df['rating'].value_counts()
# Out:
# PG-13    499
# R        442
# PG       202
# G          8
# Name: rating, dtype: int64

# %%
df_rating = pd.get_dummies(df['rating'], drop_first=True)
df_rating.head()
# Out:
#                             PG  PG-13  R
# title
# Alice in Wonderland          1      0  0
# Iron Man 2                   0      1  0
# The Twilight Saga: Eclipse   0      1  0
# Inception                    0      1  0
# Despicable Me                1      0  0

# %%
df_rating.to_csv('data/rating')

# %% [markdown]
# Genres

# %%
df['genres'].head()
# Out:
# title
# Alice in Wonderland                                [Adventure, Family, Fantasy]
# Iron Man 2                                          [Action, Adventure, Sci-Fi]
# The Twilight Saga: Eclipse    [Action, Adventure, Drama, Fantasy, Romance, T...
# Inception                                 [Action, Adventure, Sci-Fi, Thriller]
# Despicable Me                       [Animation, Comedy, Crime, Family, Fantasy]
# Name: genres, dtype: object

# %%
type(df['genres'])
# Out:
# pandas.core.series.Series

# %%
type(df.genres[1])
# Out:
# list

# %%
df['genres'] = df.genres.astype(str)
df['genres'] = df['genres'].str.replace('[','').str.replace(']','').str.replace("'","")
df['genres']
# Out:
# <ipython-input-43-a7324a8733ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df.genres.astype(str)
# <ipython-input-43-a7324a8733ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].str.replace('[','').str.replace(']','').str.replace("'","")
# title
# Alice in Wonderland                                        Adventure, Family, Fantasy
# Iron Man 2                                                  Action, Adventure, Sci-Fi
# The Twilight Saga: Eclipse          Action, Adventure, Drama, Fantasy, Romance, Th...
# Inception                                         Action, Adventure, Sci-Fi, Thriller
# Despicable Me                               Animation, Comedy, Crime, Family, Fantasy
#                                                           ...
# The Best of Enemies                                         Biography, Drama, History
# Motherless Brooklyn                                             Crime, Drama, Mystery
# The Goldfinch                                                                   Drama
# Don't Let Go                                 Drama, Horror, Mystery, Sci-Fi, Thriller
# The Wizard of Oz 2019 Re-release                  Adventure, Family, Fantasy, Musical
# Name: genres, Length: 1151, dtype: object

# %%
df_genres = df['genres'].str.get_dummies(sep=', ')

# %%
df_genres
# Out:
#                                   Action  Adventure  Animation  Biography  \
# title
# Alice in Wonderland                    0          1          0          0
# Iron Man 2                             1          1          0          0
# The Twilight Saga: Eclipse             1          1          0          0
# Inception                              1          1          0          0
# Despicable Me                          0          0          1          0
# ...                                  ...        ...        ...        ...
# The Best of Enemies                    0          0          0          1
# Motherless Brooklyn                    0          0          0          0
# The Goldfinch                          0          0          0          0
# Don't Let Go                           0          0          0          0
# The Wizard of Oz 2019 Re-release       0          1          0          0
#
#                                   Comedy  Crime  Documentary  Drama  Family  \
# title
# Alice in Wonderland                    0      0            0      0       1
# Iron Man 2                             0      0            0      0       0
# The Twilight Saga: Eclipse             0      0            0      1       0
# Inception                              0      0            0      0       0
# Despicable Me                          1      1            0      0       1
# ...                                  ...    ...          ...    ...     ...
# The Best of Enemies                    0      0            0      1       0
# Motherless Brooklyn                    0      1            0      1       0
# The Goldfinch                          0      0            0      1       0
# Don't Let Go                           0      0            0      1       0
# The Wizard of Oz 2019 Re-release       0      0            0      0       1
#
#                                   Fantasy  ...  Horror  Music  Musical  \
# title                                      ...
# Alice in Wonderland                     1  ...       0      0        0
# Iron Man 2                              0  ...       0      0        0
# The Twilight Saga: Eclipse              1  ...       0      0        0
# Inception                               0  ...       0      0        0
# Despicable Me                           1  ...       0      0        0
# ...                                   ...  ...     ...    ...      ...
# The Best of Enemies                     0  ...       0      0        0
# Motherless Brooklyn                     0  ...       0      0        0
# The Goldfinch                           0  ...       0      0        0
# Don't Let Go                            0  ...       1      0        0
# The Wizard of Oz 2019 Re-release        1  ...       0      0        1
#
#                                   Mystery  Romance  Sci-Fi  Sport  Thriller  \
# title
# Alice in Wonderland                     0        0       0      0         0
# Iron Man 2                              0        0       1      0         0
# The Twilight Saga: Eclipse              0        1       0      0         1
# Inception                               0        0       1      0         1
# Despicable Me                           0        0       0      0         0
# ...                                   ...      ...     ...    ...       ...
# The Best of Enemies                     0        0       0      0         0
# Motherless Brooklyn                     1        0       0      0         0
# The Goldfinch                           0        0       0      0         0
# Don't Let Go                            1        0       1      0         1
# The Wizard of Oz 2019 Re-release        0        0       0      0         0
#
#                                   War  Western
# title
# Alice in Wonderland                 0        0
# Iron Man 2                          0        0
# The Twilight Saga: Eclipse          0        0
# Inception                           0        0
# Despicable Me                       0        0
# ...                               ...      ...
# The Best of Enemies                 0        0
# Motherless Brooklyn                 0        0
# The Goldfinch                       0        0
# Don't Let Go                        0        0
# The Wizard of Oz 2019 Re-release    0        0
#
# [1151 rows x 21 columns]

# %%
df_genres.to_csv('data/genres')

# %% [markdown]
# Release Date

# %%
def date_to_season(date):
    winter = [12, 1, 2]
    spring = [3, 4, 5]
    summer = [6, 7, 8]
    fall = [9, 10, 11]
    
    if date.month in winter:
        return "winter"
    elif date.month in spring:
        return "spring"
    elif date.month in summer:
        return "summer"
    else:
        return "fall"

# %%
df['date_to_season'] = df['date'].apply(date_to_season)
# Out:
# <ipython-input-49-9672994e7c63>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_to_season'] = df['date'].apply(date_to_season)

# %%
df.head()
# Out:
#                              domestic   worldwide  \
# title
# Alice in Wonderland         334191110  1025467110
# Iron Man 2                  312433331   623933331
# The Twilight Saga: Eclipse  300531751   698491347
# Inception                   292576195   826137188
# Despicable Me               251513985   543113985
#
#                                                     distributor      opening  \
# title
# Alice in Wonderland         Walt Disney Studios Motion Pictures  116101023.0
# Iron Man 2                                   Paramount Pictures  128122480.0
# The Twilight Saga: Eclipse                 Summit Entertainment   64832191.0
# Inception                                          Warner Bros.   62785337.0
# Despicable Me                                Universal Pictures   56397125.0
#
#                                  budget       date  runtime  widest rating  \
# title
# Alice in Wonderland         200000000.0 2010-03-05    108.0  3739.0     PG
# Iron Man 2                  200000000.0 2010-05-07    124.0  4390.0  PG-13
# The Twilight Saga: Eclipse   68000000.0 2010-06-30    124.0  4468.0  PG-13
# Inception                   160000000.0 2010-07-16    148.0  3792.0  PG-13
# Despicable Me                69000000.0 2010-07-09     95.0  3602.0     PG
#
#                                                                        genres  \
# title
# Alice in Wonderland                                Adventure, Family, Fantasy
# Iron Man 2                                          Action, Adventure, Sci-Fi
# The Twilight Saga: Eclipse  Action, Adventure, Drama, Fantasy, Romance, Th...
# Inception                                 Action, Adventure, Sci-Fi, Thriller
# Despicable Me                       Animation, Comedy, Crime, Family, Fantasy
#
#                            date_to_season
# title
# Alice in Wonderland                spring
# Iron Man 2                         spring
# The Twilight Saga: Eclipse         summer
# Inception                          summer
# Despicable Me                      summer

# %%
df_season = pd.get_dummies(df['date_to_season'], drop_first=True)
df_season.head()
# Out:
#                             spring  summer  winter
# title
# Alice in Wonderland              1       0       0
# Iron Man 2                       1       0       0
# The Twilight Saga: Eclipse       0       1       0
# Inception                        0       1       0
# Despicable Me                    0       1       0

# %%
df_season.to_csv('data/season')
